# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
dir_path = Path.cwd().parents[2]

data_folder = dir_path.joinpath("data/ibis/raw_manually_sorted")

df_path = data_folder.joinpath("Food.xlsx")

export_path = dir_path.joinpath("data/ibis/interim/Food.csv")

# %%
df = pd.read_excel(df_path)
df
# Out:
#                         Company Name AddCode  \
# 0                    15AD Bakery LLP   Plant
# 1       15Herbs Organic Tabs Pvt Ltd   Plant
# 2                  3F Industries Ltd   Plant
# 3                  3F Industries Ltd   Plant
# 4                  3F Industries Ltd   Plant
# ...                              ...     ...
# 6546  Zuari Envien Bioenergy Pvt Ltd   Plant
# 6547              Zydus Wellness Ltd   Plant
# 6548              Zydus Wellness Ltd   Plant
# 6549              Zyex Chemicals Llp   Plant
# 6550          Zywie Ventures Pvt Ltd   Plant
#
#                                                    Add1  \
# 0                   Plot No. P, Behind New Power House,
# 1                 Shed No. A-39, Automobile Cooperative
# 2                        Yernagudem(V), Devarapalli(M),
# 3                               P.B.N o.15,Tanuku Road,
# 4                         Survey No. 785 Burgul Village
# ...                                                 ...
# 6546  Plot No. 14 Village Khamariya Pandit, Tehsil D...
# 6547                        PO Box No. 01, Manzurgarhi,
# 6548       Plot No. 7A/ 7B, 8, Saket Industrial Estate,
# 6549                    42 H, Pahari /Sapchauli Village
# 6550                                  Plot No. 25, EPIP
#
#                                         Add2                        City  \
# 0              Street No.4,  Industrial Area                     Jodhpur
# 1                          Industrial Estate  Kappalur Industrial Estate
# 2                      West Godavari (Dist.)                  Yernagudem
# 3                                        NaN              Tadapalligudem
# 4                                Mahbubnagar                     Burgula
# ...                                      ...                         ...
# 6546               District Lakhimpur Kheri,             Khamaria Pandit
# 6547                                 Aligarh                     Aligarh
# 6548  Sarkhej Bawla Highway, Village Moraiya                     Sarkhej
# 6549                           Morena Tehsil                   Sapchauli
# 6550                                Phase II                       Baddi
#
#      Pincode        Taluk             District             State  \
# 0     342001          NaN               Nagaur         Rajasthan
# 1     625008          NaN              Madurai        Tamil Nadu
# 2     534313  Devarapalle        West Godavari    Andhra Pradesh
# 3     534101          NaN        West Godavari    Andhra Pradesh
# 4     509202          NaN         Mehboobnagar         Telangana
# ...      ...          ...                  ...               ...
# 6546     NaN   Dhaurahara                Kheri     Uttar Pradesh
# 6547  202001          NaN  Gautam Buddha Nagar     Uttar Pradesh
# 6548  382210          NaN            Ahmedabad           Gujarat
# 6549     NaN       Morena               Morena    Madhya Pradesh
# 6550  173205          NaN                Solan  Himachal Pradesh
#
#                          Tel                 Fax  \
# 0                        NaN                 NaN
# 1     80121 81818/7708066818                 NaN
# 2          Tel: 08813 210544                 NaN
# 3      Tel: 08818-222571-74,  Fax: 08818- 222172
# 4         Tel: 0-91001 07080                 NaN
# ...                      ...                 ...
# 6546                     NaN                 NaN
# 6547                     NaN                 NaN
# 6548                     NaN                 NaN
# 6549                     NaN                 NaN
# 6550                     NaN                 NaN
#
#                                              Email Names Capacity Units  \
# 0                                              NaN   NaN      NaN   NaN
# 1                                 info@18herbs.com   NaN      NaN   NaN
# 2                                              NaN   NaN       35   tph
# 3     Email: sbg@fff.co.in, sbg@airtelbroadband.in   NaN      675   tpd
# 4                          Email: udaya@3fff.co.in   NaN      NaN   NaN
# ...                                            ...   ...      ...   ...
# 6546                                           NaN   NaN      NaN   NaN
# 6547                                           NaN   NaN      NaN   NaN
# 6548                                           NaN   NaN      NaN   NaN
# 6549                                           NaN   NaN      NaN   NaN
# 6550                                           NaN   NaN      NaN   NaN
#
#      Upcoming Capacity Units.1 Captive Power Plant Capacity
# 0                  NaN     NaN                          NaN
# 1                  NaN     NaN                          NaN
# 2                  NaN     NaN               2.5 MW (Cogen)
# 3                  NaN     NaN                          NaN
# 4                  NaN     NaN                          NaN
# ...                ...     ...                          ...
# 6546               200    klpd               4.9 MW (Cogen)
# 6547               NaN     NaN                          NaN
# 6548               NaN     NaN                          NaN
# 6549               200    klpd               2.5 MW (Cogen)
# 6550               NaN     NaN                          NaN
#
# [6551 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Company Name', 'AddCode', 'Add1', 'Add2', 'City', 'Pincode', 'Taluk',
#        'District', 'State', 'Tel', 'Fax', 'Email', 'Names', 'Capacity',
#        'Units', 'Upcoming Capacity', 'Units.1',
#        'Captive Power Plant Capacity'],
#       dtype='object')

# %% [markdown]
# ### Filtering Plants

# %%
df['AddCode'].unique()
# Out:
# array(['Plant', 'Branch Office', 'Corp Office', 'Registered Office',
#        'Regional Office', 'plant', 'unit'], dtype=object)

# %%
df = df[df['AddCode'].isin(['Plant', 'plant', 'unit'])]
df.drop('AddCode',axis=1, inplace=True)
# Out:
# /tmp/ipykernel_208000/1201783998.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('AddCode',axis=1, inplace=True)

# %% [markdown]
# ### Check Duplicates

# %%
df[df.duplicated(keep=False)]
# Out:
#                                            Company Name  \
# 455                          Apollo Agro Industries Ltd
# 456                          Apollo Agro Industries Ltd
# 3250                           Magnum Sea Foods Pvt Ltd
# 3251                           Magnum Sea Foods Pvt Ltd
# 3252                           Magnum Sea Foods Pvt Ltd
# 3520                                Model Dairy Pvt Ltd
# 3521                                Model Dairy Pvt Ltd
# 4057                             P L Industries Pvt Ltd
# 4058                             P L Industries Pvt Ltd
# 4174                               Pearl Distillery Ltd
# 4175                               Pearl Distillery Ltd
# 4633                          Ruchi Soya Industries Ltd
# 4642                          Ruchi Soya Industries Ltd
# 4814  Sanjivani Agro Phale V Phule Kharedi Vikri Sah...
# 4815  Sanjivani Agro Phale V Phule Kharedi Vikri Sah...
# 5124                             Shree Ram Proteins Ltd
# 5126                             Shree Ram Proteins Ltd
# 5620                 Sri Venkatarama Oil Industries Ltd
# 5622                 Sri Venkatarama Oil Industries Ltd
# 6256                                   Veda Biofuel Ltd
# 6257                                   Veda Biofuel Ltd
# 6342                   Vindhyachal Distilleries Pvt Ltd
# 6343                   Vindhyachal Distilleries Pvt Ltd
# 6397                                Vizag Foods Pvt Ltd
# 6398                                Vizag Foods Pvt Ltd
#
#                                                    Add1  \
# 455                     Unjha - Siddhpur State Highway,
# 456                     Unjha - Siddhpur State Highway,
# 3250               Village Botanda, P.O. Nilagiripatna,
# 3251               Village Botanda, P.O. Nilagiripatna,
# 3252               Village Botanda, P.O. Nilagiripatna,
# 3520                                         Nidamanuru
# 3521                                         Nidamanuru
# 4057                         North East Mega Food Park,
# 4058                         North East Mega Food Park,
# 4174                    Magunta Subbirami Reddy Factory
# 4175                    Magunta Subbirami Reddy Factory
# 4633                                   Village Butibori
# 4642                                   Village Butibori
# 4814                                       Gat. No. 23,
# 4815                                       Gat. No. 23,
# 5124  B-206, Second Floor, The Imperial Heights, Opp...
# 5126  B-206, Second Floor, The Imperial Heights, Opp...
# 5620                             15-7-66, Hussainpuram,
# 5622                             15-7-66, Hussainpuram,
# 6256                                   Kuppam Anchorage
# 6257                                   Kuppam Anchorage
# 6342                                         Pilukhedi,
# 6343                                         Pilukhedi,
# 6397                      Survey No. 162 Paradesipalem,
# 6398                      Survey No. 162 Paradesipalem,
#
#                                Add2            City Pincode         Taluk  \
# 455                  At Brahmanwada     Brahmanwada  384215           NaN
# 456                  At Brahmanwada     Brahmanwada  384215           NaN
# 3250                         Jankia    Nilgiripatna  752019           NaN
# 3251                         Jankia    Nilgiripatna  752019           NaN
# 3252                         Jankia    Nilgiripatna  752019           NaN
# 3520                            NaN      Vijayawada  521104           NaN
# 3521                            NaN      Vijayawada  521104           NaN
# 4057                          Tihu,         Nalbari     NaN         Baska
# 4058                          Tihu,         Nalbari     NaN         Baska
# 4174                 Singarayakonda  Singarayakonda  523101     Donakonda
# 4175                 Singarayakonda  Singarayakonda  523101     Donakonda
# 4633                            NaN        Butibori  441122           NaN
# 4642                            NaN        Butibori  441122           NaN
# 4814              At & P O Tamdalge      Tamadalage  416101           NaN
# 4815              At & P O Tamdalge      Tamadalage  416101           NaN
# 5124             150 Feet Ring Road          Rajkot  360005           NaN
# 5126             150 Feet Ring Road          Rajkot  360005           NaN
# 5620                            NaN        Samalkot  533440           NaN
# 5622                            NaN        Samalkot  533440           NaN
# 6256  East Point Colony, Beach Road     Kandivalasa  535204  Pusapatirega
# 6257  East Point Colony, Beach Road     Kandivalasa  535204  Pusapatirega
# 6342            Tehsil Narsinghgarh      Pilu Khedi     NaN  Narsinghgarh
# 6343            Tehsil Narsinghgarh      Pilu Khedi     NaN  Narsinghgarh
# 6397                    Madhurawada  Visakhapatinam  530040           NaN
# 6398                    Madhurawada  Visakhapatinam  530040           NaN
#
#            District           State  \
# 455         Mehsana         Gujarat
# 456         Mehsana         Gujarat
# 3250         Khurda          Odisha
# 3251         Khurda          Odisha
# 3252         Khurda          Odisha
# 3520        Krishna  Andhra Pradesh
# 3521        Krishna  Andhra Pradesh
# 4057        Nalbari           Assam
# 4058        Nalbari           Assam
# 4174       Prakasam  Andhra Pradesh
# 4175       Prakasam  Andhra Pradesh
# 4633         Nagpur     Maharashtra
# 4642         Nagpur     Maharashtra
# 4814       Kolhapur     Maharashtra
# 4815       Kolhapur     Maharashtra
# 5124         Rajkot         Gujarat
# 5126         Rajkot         Gujarat
# 5620  East Godavari  Andhra Pradesh
# 5622  East Godavari  Andhra Pradesh
# 6256   Vizianagaram  Andhra Pradesh
# 6257   Vizianagaram  Andhra Pradesh
# 6342        Rajgarh  Madhya Pradesh
# 6343        Rajgarh  Madhya Pradesh
# 6397  Visakhapatnam  Andhra Pradesh
# 6398  Visakhapatnam  Andhra Pradesh
#
#                                                     Tel                Fax  \
# 455                        0-997 989 2783 /02767 282417                NaN
# 456                        0-997 989 2783 /02767 282417                NaN
# 3250                               0674-2587100/2583101                NaN
# 3251                               0674-2587100/2583101                NaN
# 3252                               0674-2587100/2583101                NaN
# 3520              Tel: 9666924999 /0866-2842777/2842396  Fax: 0866-2842111
# 3521              Tel: 9666924999 /0866-2842777/2842396  Fax: 0866-2842111
# 4057                                       0-9436164900                NaN
# 4058                                       0-9436164900                NaN
# 4174                      Tel: 9949331633 /087982 23695                NaN
# 4175                      Tel: 9949331633 /087982 23695                NaN
# 4633                                                NaN                NaN
# 4642                                                NaN                NaN
# 4814                                        09850844999                NaN
# 4815                                        09850844999                NaN
# 5124                                       0281 2581152                NaN
# 5126                                       0281 2581152                NaN
# 5620  0884 - 2327802 - 04 /076600 01042/0884-2327802...            2327805
# 5622  0884 - 2327802 - 04 /076600 01042/0884-2327802...            2327805
# 6256                   Tel: 0891 - 2711888 / 9603536113                NaN
# 6257                   Tel: 0891 - 2711888 / 9603536113                NaN
# 6342      0755 2555383, 2555384, 2555366 /0-94250 08208                NaN
# 6343      0755 2555383, 2555384, 2555366 /0-94250 08208                NaN
# 6397                                    Tel: 9347226768                NaN
# 6398                                    Tel: 9347226768                NaN
#
#                             Email Names Capacity Units Upcoming Capacity  \
# 455         apollo.agro@yahoo.com   NaN      NaN   NaN               NaN
# 456         apollo.agro@yahoo.com   NaN      NaN   NaN               NaN
# 3250  cssatpathy@magnum-india.com   NaN      NaN   NaN               NaN
# 3251  cssatpathy@magnum-india.com   NaN      NaN   NaN               NaN
# 3252  cssatpathy@magnum-india.com   NaN      NaN   NaN               NaN
# 3520                          NaN   NaN      NaN   NaN               NaN
# 3521                          NaN   NaN      NaN   NaN               NaN
# 4057          plind2020@gmail.com   NaN      NaN   NaN               NaN
# 4058          plind2020@gmail.com   NaN      NaN   NaN               NaN
# 4174                          NaN   NaN      NaN   NaN               NaN
# 4175                          NaN   NaN      NaN   NaN               NaN
# 4633                          NaN   NaN      NaN   NaN               NaN
# 4642                          NaN   NaN      NaN   NaN               NaN
# 4814   patil.chetan.jay@gmail.com   NaN      NaN   NaN               NaN
# 4815   patil.chetan.jay@gmail.com   NaN      NaN   NaN               NaN
# 5124    info@shreeramproteins.com   NaN      NaN   NaN               NaN
# 5126    info@shreeramproteins.com   NaN      NaN   NaN               NaN
# 5620              info@svroil.com   NaN      NaN   NaN               NaN
# 5622              info@svroil.com   NaN      NaN   NaN               NaN
# 6256                          NaN   NaN      NaN   NaN               NaN
# 6257                          NaN   NaN      NaN   NaN               NaN
# 6342        vindhya@sancharnet.in   NaN      NaN   NaN               NaN
# 6343        vindhya@sancharnet.in   NaN      NaN   NaN               NaN
# 6397                          NaN   NaN      NaN   NaN               NaN
# 6398                          NaN   NaN      NaN   NaN               NaN
#
#      Units.1 Captive Power Plant Capacity
# 455      NaN                          NaN
# 456      NaN                          NaN
# 3250     NaN                          NaN
# 3251     NaN                          NaN
# 3252     NaN                          NaN
# 3520     NaN                          NaN
# 3521     NaN                          NaN
# 4057     NaN                          NaN
# 4058     NaN                          NaN
# 4174     NaN                          NaN
# 4175     NaN                          NaN
# 4633     NaN                          NaN
# 4642     NaN                          NaN
# 4814     NaN                          NaN
# 4815     NaN                          NaN
# 5124     NaN                          NaN
# 5126     NaN                          NaN
# 5620     NaN                          NaN
# 5622     NaN                          NaN
# 6256     NaN                          NaN
# 6257     NaN                          NaN
# 6342     NaN                          NaN
# 6343     NaN                          NaN
# 6397     NaN                          NaN
# 6398     NaN                          NaN

# %%
isid_cols = ['Company Name', 'Pincode', 'Add1', 'Add2']


df[df.duplicated(isid_cols,keep=False)]
# Out:
#                           Company Name                            Add1  \
# 17                      A B Sugars Ltd                   Chadha Estate
# 19                      A B Sugars Ltd                   Chadha Estate
# 96          Able Oils And Agro Pvt Ltd             At & Post: Bhojpara
# 97          Able Oils And Agro Pvt Ltd             At & Post: Bhojpara
# 124    Adhiyaman Agro Products Pvt Ltd  Karimangalam Main Road, Agaram
# ...                                ...                             ...
# 6398               Vizag Foods Pvt Ltd   Survey No. 162 Paradesipalem,
# 6507  Yedeshwari Agro Products Pvt Ltd               Anandgaon Village
# 6508  Yedeshwari Agro Products Pvt Ltd               Anandgaon Village
# 6514    Yogeshwar Sugar Industries Ltd                      Laxminagar
# 6515    Yogeshwar Sugar Industries Ltd                      Laxminagar
#
#                                            Add2            City Pincode  \
# 17               Village Malaysia, P.O. Dhanura   Chadha Estate     NaN
# 19               Village Malaysia, P.O. Dhanura   Chadha Estate     NaN
# 96    Wankaner To Jetparda Road,Behind Bhojpara        Wankaner  363621
# 97    Wankaner To Jetparda Road,Behind Bhojpara        Wankaner  363621
# 124                                 Pochampalli          Agaram  635204
# ...                                         ...             ...     ...
# 6398                                Madhurawada  Visakhapatinam  530040
# 6507                                 Kaij Taluk       Anandgaon  431131
# 6508                                 Kaij Taluk       Anandgaon  431131
# 6514                                      Limba     Limba Tanda  431541
# 6515                                      Limba     Limba Tanda  431541
#
#        Taluk             District           State  \
# 17       NaN  Jyotiba Phule Nagar   Uttar Pradesh
# 19       NaN  Jyotiba Phule Nagar   Uttar Pradesh
# 96       NaN               Rajkot         Gujarat
# 97       NaN               Rajkot         Gujarat
# 124      NaN          Krishnagiri      Tamil Nadu
# ...      ...                  ...             ...
# 6398     NaN        Visakhapatnam  Andhra Pradesh
# 6507     NaN                 Beed     Maharashtra
# 6508     NaN                 Beed     Maharashtra
# 6514  Pathri             Parbhani     Maharashtra
# 6515  Pathri             Parbhani     Maharashtra
#
#                                 Tel                Fax  \
# 17                Tel: 05924-273104                NaN
# 19                Tel: 05924-273104                NaN
# 96    0-95128 22322 /0-951 283 7370                NaN
# 97                    0-95128 22322                NaN
# 124        04343-256197 /9790337073                NaN
# ...                             ...                ...
# 6398                Tel: 9347226768                NaN
# 6507  Tel: 02445-251316 /8411974301                NaN
# 6508  Tel: 02445-251316 /8411974301                NaN
# 6514      Tel: 02451-261507 /261527  Fax: 02451-261537
# 6515      Tel: 02451-261507 /261527  Fax: 02451-261537
#
#                                        Email  \
# 17              Email: capi@chadhasugars.com
# 19              Email: capi@chadhasugars.com
# 96                         info@ableoils.com
# 97                         info@ableoils.com
# 124                  adhiyamanagro@gmail.com
# ...                                      ...
# 6398                                     NaN
# 6507                 Email: yapltd@gmail.com
# 6508                 Email: yapltd@gmail.com
# 6514  Email: yogeshwari_sugar@rediffmail.com
# 6515  Email: yogeshwari_sugar@rediffmail.com
#
#                                                   Names Capacity Units  \
# 17                                                  NaN      NaN   NaN
# 19    Plant Make : TRIVENI /Milling Plants : 2 sets ...     8300   tcd
# 96                                                  NaN      NaN   NaN
# 97                                                  NaN      NaN   NaN
# 124                                                 NaN      NaN   NaN
# ...                                                 ...      ...   ...
# 6398                                                NaN      NaN   NaN
# 6507                                                NaN       45  klpd
# 6508  Plant Make : MERU /Milling Plants : 1 Set Kniv...     3500   tcd
# 6514  Plant Make : THYSSEN KRUPP /Milling Plants : Z...     1000   tcd
# 6515                                                NaN      NaN   NaN
#
#      Upcoming Capacity Units.1 Captive Power Plant Capacity
# 17                 180    klpd                         30MW
# 19                 NaN     NaN                          NaN
# 96                 NaN     NaN                          NaN
# 97                 NaN     NaN                          NaN
# 124                NaN     NaN                          NaN
# ...                ...     ...                          ...
# 6398               NaN     NaN                          NaN
# 6507                65    klpd                          NaN
# 6508               NaN     NaN                          NaN
# 6514               NaN     NaN                    12 MW (U)
# 6515               110    klpd               1.5 MW (Cogen)
#
# [309 rows x 17 columns]

# %% [markdown]
# ### Cleaning Column names and Columns

# %%
cols = df.columns

cols = [x.replace(" ", "_").lower() for x in cols]

cols
# Out:
# ['company_name',
#  'add1',
#  'add2',
#  'city',
#  'pincode',
#  'taluk',
#  'district',
#  'state',
#  'tel',
#  'fax',
#  'email',
#  'names',
#  'capacity',
#  'units',
#  'upcoming_capacity',
#  'units.1',
#  'captive_power_plant_capacity']

# %%
df.columns = cols

df.rename(columns={
    
   "units":"unit",
   "units.1":"upcoming_capacity_unit"
}, inplace=True)
# Out:
# /tmp/ipykernel_208000/19474581.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={

# %%
df.drop(['tel',
 'fax',
 'email',
 'names',
 'captive_power_plant_capacity'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_208000/3798550352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['tel',

# %%
df
# Out:
#                         company_name  \
# 0                    15AD Bakery LLP
# 1       15Herbs Organic Tabs Pvt Ltd
# 2                  3F Industries Ltd
# 3                  3F Industries Ltd
# 4                  3F Industries Ltd
# ...                              ...
# 6546  Zuari Envien Bioenergy Pvt Ltd
# 6547              Zydus Wellness Ltd
# 6548              Zydus Wellness Ltd
# 6549              Zyex Chemicals Llp
# 6550          Zywie Ventures Pvt Ltd
#
#                                                    add1  \
# 0                   Plot No. P, Behind New Power House,
# 1                 Shed No. A-39, Automobile Cooperative
# 2                        Yernagudem(V), Devarapalli(M),
# 3                               P.B.N o.15,Tanuku Road,
# 4                         Survey No. 785 Burgul Village
# ...                                                 ...
# 6546  Plot No. 14 Village Khamariya Pandit, Tehsil D...
# 6547                        PO Box No. 01, Manzurgarhi,
# 6548       Plot No. 7A/ 7B, 8, Saket Industrial Estate,
# 6549                    42 H, Pahari /Sapchauli Village
# 6550                                  Plot No. 25, EPIP
#
#                                         add2                        city  \
# 0              Street No.4,  Industrial Area                     Jodhpur
# 1                          Industrial Estate  Kappalur Industrial Estate
# 2                      West Godavari (Dist.)                  Yernagudem
# 3                                        NaN              Tadapalligudem
# 4                                Mahbubnagar                     Burgula
# ...                                      ...                         ...
# 6546               District Lakhimpur Kheri,             Khamaria Pandit
# 6547                                 Aligarh                     Aligarh
# 6548  Sarkhej Bawla Highway, Village Moraiya                     Sarkhej
# 6549                           Morena Tehsil                   Sapchauli
# 6550                                Phase II                       Baddi
#
#      pincode        taluk             district             state capacity  \
# 0     342001          NaN               Nagaur         Rajasthan      NaN
# 1     625008          NaN              Madurai        Tamil Nadu      NaN
# 2     534313  Devarapalle        West Godavari    Andhra Pradesh       35
# 3     534101          NaN        West Godavari    Andhra Pradesh      675
# 4     509202          NaN         Mehboobnagar         Telangana      NaN
# ...      ...          ...                  ...               ...      ...
# 6546     NaN   Dhaurahara                Kheri     Uttar Pradesh      NaN
# 6547  202001          NaN  Gautam Buddha Nagar     Uttar Pradesh      NaN
# 6548  382210          NaN            Ahmedabad           Gujarat      NaN
# 6549     NaN       Morena               Morena    Madhya Pradesh      NaN
# 6550  173205          NaN                Solan  Himachal Pradesh      NaN
#
#      unit upcoming_capacity upcoming_capacity_unit
# 0     NaN               NaN                    NaN
# 1     NaN               NaN                    NaN
# 2     tph               NaN                    NaN
# 3     tpd               NaN                    NaN
# 4     NaN               NaN                    NaN
# ...   ...               ...                    ...
# 6546  NaN               200                   klpd
# 6547  NaN               NaN                    NaN
# 6548  NaN               NaN                    NaN
# 6549  NaN               200                   klpd
# 6550  NaN               NaN                    NaN
#
# [6455 rows x 12 columns]

# %%
df.to_csv(export_path, index=False)
