# %%
import pandas as pd
from pathlib import Path

# %%
dir_path = Path.cwd().parents[2]

data_folder = dir_path.joinpath("data/ibis/raw_manually_sorted")

df_path = data_folder.joinpath("Cement.xlsx")

export_path = dir_path.joinpath("data/ibis/interim/Cement.csv")

# %%
df = pd.read_excel(df_path)
df
# Out:
#                            Company Name        AddCode  \
# 0                  Aadi Cements Pvt Ltd  Branch Office
# 1                  Aadi Cements Pvt Ltd          Plant
# 2                Abhaya Cements Pvt Ltd          Plant
# 3    Absolute Cement & Polymers Pvt Ltd          Plant
# 4                    Abu Industries Ltd          Plant
# ..                                  ...            ...
# 673         Zaffron Enterprises Pvt Ltd          Plant
# 674                   Zuari Cements Ltd          Plant
# 675                   Zuari Cements Ltd          Plant
# 676                   Zuari Cements Ltd          Plant
# 677                   Zuari Cements Ltd          Plant
#
#                                               Add1  \
# 0                       Valsana Road, Opp. College
# 1                          Block No. 22, Bakarpura
# 2                                         Nadikudi
# 3                         Plot No. 6/7, Udairampur
# 4                                    Labad Village
# ..                                             ...
# 673                                Village Khonmoh
# 674                          Solapur Grinding Unit
# 675                    Krishna Nagar, Yerraguntla,
# 676  P O Dondapadu (Formerly Shree Vishnu Cements)
# 677                          Chennai Grinding Unit
#
#                            Add2         City   Pincode         Taluk  \
# 0                           NaN        Panol  383430.0          Idar
# 1                    Idar Taluk    Bakarpura       NaN          Idar
# 2                    Dachepalli     Nadikudi  522414.0    Dachepalle
# 3       Nangla, Dhaulana Tehsil     Dhaulana       NaN         Hapur
# 4                           NaN        Labad       NaN           NaN
# ..                          ...          ...       ...           ...
# 673                    Srinagar     Srinagar  191104.0           NaN
# 674                Auj Village,          Auj  413221.0           NaN
# 675             Dist. – Kadapa,  Yerraguntla  516309.0     Prodattur
# 676                   Sitapuram   Donda Padu  508246.0  Mellacheruvu
# 677  Ambedkar Street, Athipattu      Chennai  600120.0           NaN
#
#         District            State  \
# 0    Sabarkantha          Gujarat
# 1    Sabarkantha          Gujarat
# 2         Guntur   Andhra Pradesh
# 3      Ghaziabad    Uttar Pradesh
# 4           Dhar   Madhya Pradesh
# ..           ...              ...
# 673     Srinagar  Jammu & Kashmir
# 674      Solapur      Maharashtra
# 675     Cuddapah   Andhra Pradesh
# 676    Nalagonda        Telangana
# 677   Tiruvallur       Tamil Nadu
#
#                                                 Tel                  Fax  \
# 0                                Tel: 0-76000 52020    Fax: 079-26873408
# 1                        Tel: 02778-250318 / 250319                  NaN
# 2                                 Tel: 0-9246222199                  NaN
# 3                 Tel: 0-98376 26318 /0-99350 55590                  NaN
# 4                                Tel: 0-99260-09545                  NaN
# ..                                              ...                  ...
# 673                                             NaN                  NaN
# 674                               Tel: 0217-2500750                  NaN
# 675  Tel: 08563 - 275102 / 275107 / 275108 / 275195          Fax: 275195
# 676                    Tel: 8683235232 / 8683235107  Fax: 08683 - 235229
# 677                               Tel: 044-27960027        Fax: 27960028
#
#                               Email  \
# 0                               NaN
# 1                               NaN
# 2     Email: abhayacements@yahoo.in
# 3                               NaN
# 4                               NaN
# ..                              ...
# 673                             NaN
# 674  Email: deepak.kakkar@zcltd.com
# 675         Email: zclygl@zcltd.com
# 676        Email: svclspm@zcltd.com
# 677          Email: zclgu@zcltd.com
#
#                                                  Names  Capacity Units  \
# 0                                                  NaN       NaN   NaN
# 1                                                  NaN       0.1  mtpa
# 2                                                  NaN       NaN   NaN
# 3                                                  NaN       NaN   NaN
# 4                                                  NaN    9000.0   tpa
# ..                                                 ...       ...   ...
# 673                                                NaN       NaN   NaN
# 674  Deepak Kakkar, (0-94154 12000) (deepak.kakkar@...       NaN   NaN
# 675    GNB Rao, Sr. Vice President (gnb.rao@zcltd.com)       4.6  mtpa
# 676  K Papa Rao, Plant Head, (k.paparao@zcltd.com) ...       1.4  mtpa
# 677  Ramesh Babu SP, Asst.Gen.Mgr(Production), (p.r...       1.0  mtpa
#
#     Upcoming Capacity Units.1 Captive Power Plant Capacity
# 0                 NaN     NaN                          NaN
# 1                 NaN     NaN                          NaN
# 2                 132     tpd                          NaN
# 3                 0.6    mtpa                          NaN
# 4                 NaN     NaN                          NaN
# ..                ...     ...                          ...
# 673               200     tpd                          NaN
# 674               NaN     NaN                          NaN
# 675               NaN     NaN                          NaN
# 676               NaN     NaN                         6 MW
# 677               NaN     NaN                          NaN
#
# [678 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Company Name', 'AddCode', 'Add1', 'Add2', 'City', 'Pincode', 'Taluk',
#        'District', 'State', 'Tel', 'Fax', 'Email', 'Names', 'Capacity',
#        'Units', 'Upcoming Capacity', 'Units.1',
#        'Captive Power Plant Capacity'],
#       dtype='object')

# %% [markdown]
# ### Filtering Plants

# %%
df['AddCode'].unique()
# Out:
# array(['Branch Office', 'Plant', 'Corp Office', 'Registered Office',
#        'Project Office', 'Head Office', 'Site', 'Regional Office',
#        'Marketing Office', 'HO/Corp Office', 'Site Office', nan],
#       dtype=object)

# %%
df = df[df['AddCode']=='Plant']
df.drop('AddCode',axis=1, inplace=True)
# Out:
# /tmp/ipykernel_25098/1743636810.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('AddCode',axis=1, inplace=True)

# %% [markdown]
# ### Check Duplicates

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Company Name, Add1, Add2, City, Pincode, Taluk, District, State, Tel, Fax, Email, Names, Capacity, Units, Upcoming Capacity, Units.1, Captive Power Plant Capacity]
# Index: []

# %%
isid_cols = ['Company Name', 'Pincode', 'Add1', 'Add2']


df[df.duplicated(isid_cols,keep=False)]
# Out:
#                      Company Name              Add1                Add2  \
# 517  Shree Gopal Concrete Pvt Ltd  Shreegopal House  Rambagan, Raniganj
# 518  Shree Gopal Concrete Pvt Ltd  Shreegopal House  Rambagan, Raniganj
#
#          City   Pincode Taluk          District        State  \
# 517  Durgapur  733121.0   NaN  Dakshin Dinajpur  West Bengal
# 518  Durgapur  733121.0   NaN  Dakshin Dinajpur  West Bengal
#
#                    Tel                Fax                          Email  \
# 517  Tel: 0341 3267708  Fax: 0341 3267708  Email: sgpl151@rediffmail.com
# 518  Tel: 0341 3267708  Fax: 0341 3267708  Email: sgpl151@rediffmail.com
#
#     Names  Capacity Units Upcoming Capacity Units.1  \
# 517   NaN     500.0   tpd               NaN     NaN
# 518   NaN     300.0   tpd               NaN     NaN
#
#     Captive Power Plant Capacity
# 517                          NaN
# 518                          NaN

# %% [markdown]
# ### Cleaning Column names and Columns

# %%
cols = df.columns

cols = [x.replace(" ", "_").lower() for x in cols]

cols
# Out:
# ['company_name',
#  'add1',
#  'add2',
#  'city',
#  'pincode',
#  'taluk',
#  'district',
#  'state',
#  'tel',
#  'fax',
#  'email',
#  'names',
#  'capacity',
#  'units',
#  'upcoming_capacity',
#  'units.1',
#  'captive_power_plant_capacity']

# %%
df.columns = cols

df.rename(columns={
    "units.1":"upcoming_capacity_unit"
}, inplace=True)
# Out:
# /tmp/ipykernel_25098/461494988.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={

# %%
df.drop(['tel',
 'fax',
 'email',
 'names',
 'captive_power_plant_capacity'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_25098/3798550352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['tel',

# %%
df
# Out:
#                            company_name  \
# 1                  Aadi Cements Pvt Ltd
# 2                Abhaya Cements Pvt Ltd
# 3    Absolute Cement & Polymers Pvt Ltd
# 4                    Abu Industries Ltd
# 6                               ACC Ltd
# ..                                  ...
# 673         Zaffron Enterprises Pvt Ltd
# 674                   Zuari Cements Ltd
# 675                   Zuari Cements Ltd
# 676                   Zuari Cements Ltd
# 677                   Zuari Cements Ltd
#
#                                               add1  \
# 1                          Block No. 22, Bakarpura
# 2                                         Nadikudi
# 3                         Plot No. 6/7, Udairampur
# 4                                    Labad Village
# 6              Sindri Cement Works (Grinding Unit)
# ..                                             ...
# 673                                Village Khonmoh
# 674                          Solapur Grinding Unit
# 675                    Krishna Nagar, Yerraguntla,
# 676  P O Dondapadu (Formerly Shree Vishnu Cements)
# 677                          Chennai Grinding Unit
#
#                            add2         city   pincode         taluk  \
# 1                    Idar Taluk    Bakarpura       NaN          Idar
# 2                    Dachepalli     Nadikudi  522414.0    Dachepalle
# 3       Nangla, Dhaulana Tehsil     Dhaulana       NaN         Hapur
# 4                           NaN        Labad       NaN           NaN
# 6              P.O. ACC Colony,      Dhanbad  828124.0           NaN
# ..                          ...          ...       ...           ...
# 673                    Srinagar     Srinagar  191104.0           NaN
# 674                Auj Village,          Auj  413221.0           NaN
# 675             Dist. – Kadapa,  Yerraguntla  516309.0     Prodattur
# 676                   Sitapuram   Donda Padu  508246.0  Mellacheruvu
# 677  Ambedkar Street, Athipattu      Chennai  600120.0           NaN
#
#         district            state  capacity units upcoming_capacity  \
# 1    Sabarkantha          Gujarat       0.1  mtpa               NaN
# 2         Guntur   Andhra Pradesh       NaN   NaN               132
# 3      Ghaziabad    Uttar Pradesh       NaN   NaN               0.6
# 4           Dhar   Madhya Pradesh    9000.0   tpa               NaN
# 6            NaN        Jharkhand       2.5  mtpa               2.0
# ..           ...              ...       ...   ...               ...
# 673     Srinagar  Jammu & Kashmir       NaN   NaN               200
# 674      Solapur      Maharashtra       NaN   NaN               NaN
# 675     Cuddapah   Andhra Pradesh       4.6  mtpa               NaN
# 676    Nalagonda        Telangana       1.4  mtpa               NaN
# 677   Tiruvallur       Tamil Nadu       1.0  mtpa               NaN
#
#     upcoming_capacity_unit
# 1                      NaN
# 2                      tpd
# 3                     mtpa
# 4                      NaN
# 6                     mtpa
# ..                     ...
# 673                    tpd
# 674                    NaN
# 675                    NaN
# 676                    NaN
# 677                    NaN
#
# [623 rows x 12 columns]

# %%
df.to_csv(export_path, index=False)
