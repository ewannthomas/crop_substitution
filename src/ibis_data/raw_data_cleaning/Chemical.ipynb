# %%
import pandas as pd
from pathlib import Path

# %%
dir_path = Path.cwd().parents[2]

data_folder = dir_path.joinpath("data/ibis/raw_manually_sorted")

df_path = data_folder.joinpath("Chemical.xlsx")

export_path = dir_path.joinpath("data/ibis/interim/Chemical.csv")

# %%
df = pd.read_excel(df_path)
df
# Out:
#                    Company Name        AddCode  \
# 0     3N Composite Products LLP          Plant
# 1       A B Mauri India Pvt Ltd          Plant
# 2       A B Mauri India Pvt Ltd          Plant
# 3       A B Mauri India Pvt Ltd          Plant
# 4       A B Mauri India Pvt Ltd  Branch Office
# ...                         ...            ...
# 3292        Zest Aromas Pvt Ltd          Plant
# 3293         Zizer Polymers LLP          Plant
# 3294         Zizer Polymers LLP          Plant
# 3295             Zydex Organics          Plant
# 3296             Zydex Organics  Branch Office
#
#                                                    Add1  \
# 0     12th Kilometer Milestone, Udaipur - Banswara R...
# 1                      D-7/2A MIDC Area, Lote Parshuram
# 2                        C-70-73 UPSIDC Industrial Area
# 3                 Plot 24,Cochin Export Processing Zone
# 4              Worldmark-1, Village Maidawas, Sector 65
# ...                                                 ...
# 3292                              Plot No. 59/1 Piparia
# 3293                                Survey No. 93 Palki
# 3294                                Survey No. 93 Palki
# 3295                              E-12, MIDC Chincholi,
# 3296   139 B.D.A Industrial Surburb, 6th Main 3rd Cross
#
#                                    Add2          City Pincode Taluk  \
# 0                  Dakan Kotra, Udaipur       Udaipur  313001   NaN
# 1      Taluka Khed, District: Ratnagiri          Lote  415722   NaN
# 2     District: Bulandshar, Sikandrabad  Sikandarabad  203205   NaN
# 3                                   NaN      Kakkanad  682030   NaN
# 4                              Gurugram       Gurgaon  122001   NaN
# ...                                 ...           ...     ...   ...
# 3292                                NaN      Silvassa  396230   NaN
# 3293                   Bhadiyad Village         Morbi  363642   NaN
# 3294                   Bhadiyad Village         Morbi  363642   NaN
# 3295                        Tal.: Mohol     Chincholi  413255   NaN
# 3296      Tumkur Main Road, Peenya Post     Bangalore  560058   NaN
#
#          District                 State                                 Tel  \
# 0         Udaipur             Rajasthan                                 NaN
# 1       Ratnagiri           Maharashtra                  Tel: 02356-2726 75
# 2     Bulandshahr         Uttar Pradesh                  Tel: 05735-2222 48
# 3       Ernakulam                Kerala       Tel: 0484-2413 048 / 2413 068
# 4         Gurgaon               Haryana           Tel: 0124 – 6191700 / 701
# ...           ...                   ...                                 ...
# 3292        Daman  Dadra Nagar & Haveli                                 NaN
# 3293       Rajkot               Gujarat  0-8866304018/9099928666/9825764345
# 3294       Rajkot               Gujarat  0-8866304018/9099928666/9825764345
# 3295      Solapur           Maharashtra                                 NaN
# 3296    Bangalore             Karnataka                   Tel: 095382 21796
#
#                      Fax                           Email Names Capacity Unit  \
# 0                    NaN                             NaN   NaN      NaN  NaN
# 1     Fax: 02356-2727 79   Email: care.india@abmauri.com   NaN      NaN  NaN
# 2                    NaN   Email: care.india@abmauri.com   NaN      NaN  NaN
# 3     Fax: 0484-2413 050                             NaN   NaN      NaN  NaN
# 4                    NaN                             NaN   NaN      NaN  NaN
# ...                  ...                             ...   ...      ...  ...
# 3292                 NaN                             NaN   NaN      NaN  NaN
# 3293                 NaN                             NaN   NaN      NaN  NaN
# 3294                 NaN                             NaN   NaN      NaN  NaN
# 3295                 NaN  Email: zydexorganics@yahoo.com   NaN      NaN  NaN
# 3296                 NaN                             NaN   NaN      NaN  NaN
#
#      Upcoming Capacity Units Captive Power Plant Capacity
# 0                  NaN   NaN                          NaN
# 1                  NaN   NaN                          NaN
# 2                  NaN   NaN                          NaN
# 3                  NaN   NaN                          NaN
# 4                  NaN   NaN                          NaN
# ...                ...   ...                          ...
# 3292               NaN   NaN                          NaN
# 3293               NaN   NaN                          NaN
# 3294               NaN   NaN                          NaN
# 3295               NaN   NaN                          NaN
# 3296               NaN   NaN                          NaN
#
# [3297 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Company Name', 'AddCode', 'Add1', 'Add2', 'City', 'Pincode', 'Taluk',
#        'District', 'State', 'Tel', 'Fax', 'Email', 'Names', 'Capacity', 'Unit',
#        'Upcoming Capacity', 'Units', 'Captive Power Plant Capacity'],
#       dtype='object')

# %% [markdown]
# ### Filtering Plants

# %%
df['AddCode'].unique()
# Out:
# array(['Plant', 'Branch Office', 'Silicone Division', 'Corp Office', nan,
#        'Registered Office', 'HO/Corp Office', 'Head Office'], dtype=object)

# %%
df[df['AddCode'].isna()]
# Out:
#                                     Company Name AddCode  \
# 640  Chemical Construction International Pvt Ltd     NaN
# 799                    Delight Chemicals Pvt Ltd     NaN
#
#                                    Add1                                  Add2  \
# 640  205 Kusal Bazar, 32-33 Nehru Place                                   NaN
# 799           Gut #53, Mauza Ganeshpur,  Zari Zamini Taluk, Yavatmal District
#
#           City Pincode Taluk  District        State                Tel  \
# 640  New Delhi  110019   NaN     Delhi        Delhi  Tel: 011-26419399
# 799   Mukutban  445319   NaN  Yavatmal  Maharashtra                NaN
#
#                    Fax Email Names Capacity Unit Upcoming Capacity Units  \
# 640  Fax: 011-29552514   NaN   NaN      NaN  NaN               NaN   NaN
# 799                NaN   NaN   NaN      NaN  NaN               NaN   NaN
#
#     Captive Power Plant Capacity
# 640                          NaN
# 799                          NaN

# %%
df = df[df['AddCode']=='Plant']
df.drop('AddCode',axis=1, inplace=True)
# Out:
# /tmp/ipykernel_26636/1743636810.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('AddCode',axis=1, inplace=True)

# %% [markdown]
# ### Check Duplicates

# %% [markdown]
# In paper directory there are 2 line by line duplicates. Removing these.

# %%
df[df.duplicated(keep=False)]
# Out:
#                    Company Name                 Add1              Add2  \
# 2564  Sheetal Chemicals Pvt Ltd             Bollaram   Industrial Area
# 2565  Sheetal Chemicals Pvt Ltd             Bollaram   Industrial Area
# 3293         Zizer Polymers LLP  Survey No. 93 Palki  Bhadiyad Village
# 3294         Zizer Polymers LLP  Survey No. 93 Palki  Bhadiyad Village
#
#            City Pincode Taluk    District      State  \
# 2564  Hyderabad  500010   NaN  Rangareddy  Telangana
# 2565  Hyderabad  500010   NaN  Rangareddy  Telangana
# 3293      Morbi  363642   NaN      Rajkot    Gujarat
# 3294      Morbi  363642   NaN      Rajkot    Gujarat
#
#                                      Tel  Fax Email Names Capacity Unit  \
# 2564         Tel: 9346788288, 8099477781  NaN   NaN   NaN      NaN  NaN
# 2565         Tel: 9346788288, 8099477781  NaN   NaN   NaN      NaN  NaN
# 3293  0-8866304018/9099928666/9825764345  NaN   NaN   NaN      NaN  NaN
# 3294  0-8866304018/9099928666/9825764345  NaN   NaN   NaN      NaN  NaN
#
#      Upcoming Capacity Units Captive Power Plant Capacity
# 2564               NaN   NaN                          NaN
# 2565               NaN   NaN                          NaN
# 3293               NaN   NaN                          NaN
# 3294               NaN   NaN                          NaN

# %%
isid_cols = ['Company Name', 'Pincode', 'Add1', 'Add2']


df[df.duplicated(isid_cols,keep=False)]
# Out:
#                       Company Name                              Add1  \
# 347              Arvind Industries            A-2 724, 40 Shed Area,
# 348              Arvind Industries            A-2 724, 40 Shed Area,
# 1295             India Glycols Ltd              A-1, Industrial Area
# 1296             India Glycols Ltd              A-1, Industrial Area
# 1323          Indo Colchem Pvt Ltd             Plot No.36, Phase II,
# 1324          Indo Colchem Pvt Ltd             Plot No.36, Phase II,
# 1591   Krishna Finechem Industries            C-1/74, 100 Shed Area,
# 1592   Krishna Finechem Industries            C-1/74, 100 Shed Area,
# 1731                 Mahi Polymers       A/4, Yogeshwar Park Society
# 1732                 Mahi Polymers       A/4, Yogeshwar Park Society
# 1816                 Mehul Dyechem                        1803, GIDC
# 1817                 Mehul Dyechem                        1803, GIDC
# 2269       R R Chemical Industries       Plot No. 1001/2, 4th Phase,
# 2270       R R Chemical Industries       Plot No. 1001/2, 4th Phase,
# 2564     Sheetal Chemicals Pvt Ltd                          Bollaram
# 2565     Sheetal Chemicals Pvt Ltd                          Bollaram
# 2580  Shiv Shakti Acid & Chemicals          Plot No. 215, 2nd Phase,
# 2581  Shiv Shakti Acid & Chemicals          Plot No. 215, 2nd Phase,
# 3148    Vapi Oxide Colours Pvt Ltd  Plot No. 794, 794/A, 794/B, GIDC
# 3149    Vapi Oxide Colours Pvt Ltd  Plot No. 794, 794/A, 794/B, GIDC
# 3293            Zizer Polymers LLP               Survey No. 93 Palki
# 3294            Zizer Polymers LLP               Survey No. 93 Palki
#
#                                      Add2        City Pincode Taluk  \
# 347                                 GIDC,        Vapi  396195   NaN
# 348                                 GIDC,        Vapi  396195   NaN
# 1295                Bazpur Road, Kashipur    Kashipur  244713   NaN
# 1296                Bazpur Road, Kashipur    Kashipur  244713   NaN
# 1323                     G.I.D.C. Estate,       Vatva  382445   NaN
# 1324                     G.I.D.C. Estate,       Vatva  382445   NaN
# 1591                                GIDC,        Vapi  396195   NaN
# 1592                                GIDC,        Vapi  396195   NaN
# 1731  Opp: Ratnaba Schools, Thakkar Nagar   Ahmedabad  380001   NaN
# 1732  Opp: Ratnaba Schools, Thakkar Nagar   Ahmedabad  380001   NaN
# 1816                                  NaN  Ankleshwar  393002   NaN
# 1817                                  NaN  Ankleshwar  393002   NaN
# 2269                                GIDC,        Vapi  396195   NaN
# 2270                                GIDC,        Vapi  396195   NaN
# 2564                      Industrial Area   Hyderabad  500010   NaN
# 2565                      Industrial Area   Hyderabad  500010   NaN
# 2580            Nr. Morajri Circle, GIDC,        Vapi  396195   NaN
# 2581            Nr. Morajri Circle, GIDC,        Vapi  396195   NaN
# 3148                                  NaN        Vapi  396195   NaN
# 3149                                  NaN        Vapi  396195   NaN
# 3293                     Bhadiyad Village       Morbi  363642   NaN
# 3294                     Bhadiyad Village       Morbi  363642   NaN
#
#               District        State  \
# 347             Valsad      Gujarat
# 348             Valsad      Gujarat
# 1295  Udhamsingh Nagar  Uttaranchal
# 1296  Udhamsingh Nagar  Uttaranchal
# 1323      Gandhi Nagar      Gujarat
# 1324      Gandhi Nagar      Gujarat
# 1591            Valsad      Gujarat
# 1592            Valsad      Gujarat
# 1731         Ahmedabad      Gujarat
# 1732         Ahmedabad      Gujarat
# 1816           Bharuch      Gujarat
# 1817           Bharuch      Gujarat
# 2269            Valsad      Gujarat
# 2270            Valsad      Gujarat
# 2564        Rangareddy    Telangana
# 2565        Rangareddy    Telangana
# 2580            Valsad      Gujarat
# 2581            Valsad      Gujarat
# 3148            Valsad      Gujarat
# 3149            Valsad      Gujarat
# 3293            Rajkot      Gujarat
# 3294            Rajkot      Gujarat
#
#                                                     Tel  \
# 347          Tel: 0260-6532942 /9227859200 / 9227801345
# 348          Tel: 0260-6532942 /9227859200 / 9227801345
# 1295                          Tel: 05947-269000, 269500
# 1296                          Tel: 05947-269000, 269500
# 1323    Tel: 079-40083217 /40083218/ 19 /20 /9825045500
# 1324    Tel: 079-40083217 /40083218/ 19 /20 /9825045500
# 1591            Tel: 0260-2452535 / 2452633 /9825135393
# 1592            Tel: 0260-2452535 / 2452633 /9825135393
# 1731                       Tel: 9925037276 / 9925142545
# 1732                                    Tel: 9925142545
# 1816                                   Tel: 0261-220023
# 1817                                   Tel: 0261-220023
# 2269                      Tel: 0260-2422431 /9909924409
# 2270                      Tel: 0260-2422431 /9909924409
# 2564                        Tel: 9346788288, 8099477781
# 2565                        Tel: 9346788288, 8099477781
# 2580             Tel: 0260-2430711 / 2430249/9825130249
# 2581             Tel: 0260-2430711 / 2430249/9825130249
# 3148  Tel: 0260-2431760 / 2422016 /9820047695 / 9825...
# 3149  Tel: 0260-2431760 / 2422016 /9820047695 / 9825...
# 3293                 0-8866304018/9099928666/9825764345
# 3294                 0-8866304018/9099928666/9825764345
#
#                               Fax                              Email Names  \
# 347             Fax: 0260-2431046                                NaN   NaN
# 348             Fax: 0260-2431046           Email: thanacid@vsnl.com   NaN
# 1295            Fax: 05947-275315                                NaN   NaN
# 1296            Fax: 05947-275315                                NaN   NaN
# 1323           Fax: 079- 40083222                                NaN   NaN
# 1324           Fax: 079- 40083222          Email: export@indocol.com   NaN
# 1591                          NaN      Email: juparmar@sancharnet.in   NaN
# 1592                          NaN                                NaN   NaN
# 1731                          NaN  Email: hasmukhpatel8805@gmail.com   NaN
# 1732                          NaN  Email: hasmukhpatel8805@gmail.com   NaN
# 1816                          NaN                                NaN   NaN
# 1817                          NaN          Email: lrhirani@yahoo.com   NaN
# 2269            Fax: 0260-2422431                                NaN   NaN
# 2270            Fax: 0260-2422431      Email: rajmarakna@yahoo.co.in   NaN
# 2564                          NaN                                NaN   NaN
# 2565                          NaN                                NaN   NaN
# 2580  Fax: 0260-2430711 / 6542960    Email: shivshaktiacid@gmail.com   NaN
# 2581  Fax: 0260-2430711 / 6542960                                NaN   NaN
# 3148                          NaN                                NaN   NaN
# 3149                          NaN     Email: ishan.roveshia@voxco.in   NaN
# 3293                          NaN                                NaN   NaN
# 3294                          NaN                                NaN   NaN
#
#      Capacity  Unit Upcoming Capacity Units Captive Power Plant Capacity
# 347       NaN   NaN               NaN   NaN                          NaN
# 348       NaN   NaN               NaN   NaN                          NaN
# 1295      400  klpd               NaN   NaN                          NaN
# 1296    10000   tcd               NaN   NaN                        18 MW
# 1323      NaN   NaN               NaN   NaN                          NaN
# 1324      NaN   NaN               NaN   NaN                          NaN
# 1591      NaN   NaN               NaN   NaN                          NaN
# 1592      NaN   NaN               NaN   NaN                          NaN
# 1731      NaN   NaN               NaN   NaN                          NaN
# 1732      NaN   NaN               NaN   NaN                          NaN
# 1816      NaN   NaN               NaN   NaN                          NaN
# 1817      NaN   NaN               NaN   NaN                          NaN
# 2269      NaN   NaN               NaN   NaN                          NaN
# 2270      NaN   NaN               NaN   NaN                          NaN
# 2564      NaN   NaN               NaN   NaN                          NaN
# 2565      NaN   NaN               NaN   NaN                          NaN
# 2580      NaN   NaN               NaN   NaN                          NaN
# 2581      NaN   NaN               NaN   NaN                          NaN
# 3148      NaN   NaN               NaN   NaN                          NaN
# 3149      NaN   NaN               NaN   NaN                          NaN
# 3293      NaN   NaN               NaN   NaN                          NaN
# 3294      NaN   NaN               NaN   NaN                          NaN

# %% [markdown]
# ### Cleaning Column names and Columns

# %%
cols = df.columns

cols = [x.replace(" ", "_").lower() for x in cols]

cols
# Out:
# ['company_name',
#  'add1',
#  'add2',
#  'city',
#  'pincode',
#  'taluk',
#  'district',
#  'state',
#  'tel',
#  'fax',
#  'email',
#  'names',
#  'capacity',
#  'unit',
#  'upcoming_capacity',
#  'units',
#  'captive_power_plant_capacity']

# %%
df.columns = cols

df.rename(columns={
    "units":"upcoming_capacity_unit"
}, inplace=True)
# Out:
# /tmp/ipykernel_26636/2040414405.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={

# %%
df
# Out:
#                        company_name  \
# 0         3N Composite Products LLP
# 1           A B Mauri India Pvt Ltd
# 2           A B Mauri India Pvt Ltd
# 3           A B Mauri India Pvt Ltd
# 5           A B Mauri India Pvt Ltd
# ...                             ...
# 3291  Zenith Flavours And Chemicals
# 3292            Zest Aromas Pvt Ltd
# 3293             Zizer Polymers LLP
# 3294             Zizer Polymers LLP
# 3295                 Zydex Organics
#
#                                                    add1  \
# 0     12th Kilometer Milestone, Udaipur - Banswara R...
# 1                      D-7/2A MIDC Area, Lote Parshuram
# 2                        C-70-73 UPSIDC Industrial Area
# 3                 Plot 24,Cochin Export Processing Zone
# 5                      Chandmari Moore, P. O. Gayeshpur
# ...                                                 ...
# 3291                              117 Industrial Estate
# 3292                              Plot No. 59/1 Piparia
# 3293                                Survey No. 93 Palki
# 3294                                Survey No. 93 Palki
# 3295                              E-12, MIDC Chincholi,
#
#                                    add2          city pincode taluk  \
# 0                  Dakan Kotra, Udaipur       Udaipur  313001   NaN
# 1      Taluka Khed, District: Ratnagiri          Lote  415722   NaN
# 2     District: Bulandshar, Sikandrabad  Sikandarabad  203205   NaN
# 3                                   NaN      Kakkanad  682030   NaN
# 5             District - Nadia, Kalyani     Gayeshpur  741234   NaN
# ...                                 ...           ...     ...   ...
# 3291                     SIPCOT Estate,       Alathur  603110   NaN
# 3292                                NaN      Silvassa  396230   NaN
# 3293                   Bhadiyad Village         Morbi  363642   NaN
# 3294                   Bhadiyad Village         Morbi  363642   NaN
# 3295                        Tal.: Mohol     Chincholi  413255   NaN
#
#          district                 state  \
# 0         Udaipur             Rajasthan
# 1       Ratnagiri           Maharashtra
# 2     Bulandshahr         Uttar Pradesh
# 3       Ernakulam                Kerala
# 5           Nadia           West Bengal
# ...           ...                   ...
# 3291  Kanchipuram            Tamil Nadu
# 3292        Daman  Dadra Nagar & Haveli
# 3293       Rajkot               Gujarat
# 3294       Rajkot               Gujarat
# 3295      Solapur           Maharashtra
#
#                                                     tel                 fax  \
# 0                                                   NaN                 NaN
# 1                                    Tel: 02356-2726 75  Fax: 02356-2727 79
# 2                                    Tel: 05735-2222 48                 NaN
# 3                         Tel: 0484-2413 048 / 2413 068  Fax: 0484-2413 050
# 5     Tel: 033-2589 1684/2589 1684 / 2589 1806 / 641...  Fax: 033-2589 8481
# ...                                                 ...                 ...
# 3291                                      0-90427 11111                 NaN
# 3292                                                NaN                 NaN
# 3293                 0-8866304018/9099928666/9825764345                 NaN
# 3294                 0-8866304018/9099928666/9825764345                 NaN
# 3295                                                NaN                 NaN
#
#                                email names capacity unit upcoming_capacity  \
# 0                                NaN   NaN      NaN  NaN               NaN
# 1      Email: care.india@abmauri.com   NaN      NaN  NaN               NaN
# 2      Email: care.india@abmauri.com   NaN      NaN  NaN               NaN
# 3                                NaN   NaN      NaN  NaN               NaN
# 5      Email: care.india@abmauri.com   NaN      NaN  NaN               NaN
# ...                              ...   ...      ...  ...               ...
# 3291        zenithflavours@gmail.com   NaN      NaN  NaN               NaN
# 3292                             NaN   NaN      NaN  NaN               NaN
# 3293                             NaN   NaN      NaN  NaN               NaN
# 3294                             NaN   NaN      NaN  NaN               NaN
# 3295  Email: zydexorganics@yahoo.com   NaN      NaN  NaN               NaN
#
#      upcoming_capacity_unit captive_power_plant_capacity
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 5                       NaN                          NaN
# ...                     ...                          ...
# 3291                    NaN                          NaN
# 3292                    NaN                          NaN
# 3293                    NaN                          NaN
# 3294                    NaN                          NaN
# 3295                    NaN                          NaN
#
# [3252 rows x 17 columns]

# %%
df.drop(['tel',
 'fax',
 'email',
 'names',
 'captive_power_plant_capacity'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_26636/3798550352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['tel',

# %%
df
# Out:
#                        company_name  \
# 0         3N Composite Products LLP
# 1           A B Mauri India Pvt Ltd
# 2           A B Mauri India Pvt Ltd
# 3           A B Mauri India Pvt Ltd
# 5           A B Mauri India Pvt Ltd
# ...                             ...
# 3291  Zenith Flavours And Chemicals
# 3292            Zest Aromas Pvt Ltd
# 3293             Zizer Polymers LLP
# 3294             Zizer Polymers LLP
# 3295                 Zydex Organics
#
#                                                    add1  \
# 0     12th Kilometer Milestone, Udaipur - Banswara R...
# 1                      D-7/2A MIDC Area, Lote Parshuram
# 2                        C-70-73 UPSIDC Industrial Area
# 3                 Plot 24,Cochin Export Processing Zone
# 5                      Chandmari Moore, P. O. Gayeshpur
# ...                                                 ...
# 3291                              117 Industrial Estate
# 3292                              Plot No. 59/1 Piparia
# 3293                                Survey No. 93 Palki
# 3294                                Survey No. 93 Palki
# 3295                              E-12, MIDC Chincholi,
#
#                                    add2          city pincode taluk  \
# 0                  Dakan Kotra, Udaipur       Udaipur  313001   NaN
# 1      Taluka Khed, District: Ratnagiri          Lote  415722   NaN
# 2     District: Bulandshar, Sikandrabad  Sikandarabad  203205   NaN
# 3                                   NaN      Kakkanad  682030   NaN
# 5             District - Nadia, Kalyani     Gayeshpur  741234   NaN
# ...                                 ...           ...     ...   ...
# 3291                     SIPCOT Estate,       Alathur  603110   NaN
# 3292                                NaN      Silvassa  396230   NaN
# 3293                   Bhadiyad Village         Morbi  363642   NaN
# 3294                   Bhadiyad Village         Morbi  363642   NaN
# 3295                        Tal.: Mohol     Chincholi  413255   NaN
#
#          district                 state capacity unit upcoming_capacity  \
# 0         Udaipur             Rajasthan      NaN  NaN               NaN
# 1       Ratnagiri           Maharashtra      NaN  NaN               NaN
# 2     Bulandshahr         Uttar Pradesh      NaN  NaN               NaN
# 3       Ernakulam                Kerala      NaN  NaN               NaN
# 5           Nadia           West Bengal      NaN  NaN               NaN
# ...           ...                   ...      ...  ...               ...
# 3291  Kanchipuram            Tamil Nadu      NaN  NaN               NaN
# 3292        Daman  Dadra Nagar & Haveli      NaN  NaN               NaN
# 3293       Rajkot               Gujarat      NaN  NaN               NaN
# 3294       Rajkot               Gujarat      NaN  NaN               NaN
# 3295      Solapur           Maharashtra      NaN  NaN               NaN
#
#      upcoming_capacity_unit
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 5                       NaN
# ...                     ...
# 3291                    NaN
# 3292                    NaN
# 3293                    NaN
# 3294                    NaN
# 3295                    NaN
#
# [3252 rows x 12 columns]

# %%
df.to_csv(export_path, index=False)
