# %%
import pandas as pd
from pathlib import Path

# %%
dir_path = Path.cwd().parents[2]

data_folder = dir_path.joinpath("data/ibis/raw_manually_sorted")

df_path = data_folder.joinpath("Ceramics.xlsx")

export_path = dir_path.joinpath("data/ibis/interim/Ceramics.csv")

# %%
df = pd.read_excel(df_path)
df
# Out:
#                          Company Name AddCode                         Add1  \
# 0               A One Ceramic Pvt Ltd   Plant        8-A National Highway,
# 1    Aajveto Manufacturing Co Pvt Ltd   Plant               Lakhdhiranagar
# 2              Aarcot Ceramic Pvt Ltd   Plant  At. Rangpar Village , Morbi
# 3                        ABC Ceramics   Plant         Morbi - Jetpar Road,
# 4             Accord Ceramics Pvt Ltd   Plant        8-A, National Highway
# ..                                ...     ...                          ...
# 640               Zalawad Tiles Works   Plant                   Dharodiya,
# 641             Zarko Granito Pvt Ltd   Plant        Talaviya Sanala Road,
# 642           Zealtop Granito Pvt Ltd   Plant              Old Ghuntu Road
# 643             Zed Vitrified Pvt Ltd   Plant        8-A,National Highway,
# 644             Zibon Ceramic Pvt Ltd   Plant                  At Rangpar,
#
#                                        Add2      City   Pincode Taluk  \
# 0    Lakhdhirpur Road, Behind Savio Ceramic     Morbi  363642.0   NaN
# 1                              Navagam Road     Morbi  363641.0   NaN
# 2                              Jetpar Road,     Morbi  363642.0   NaN
# 3                              At. Rangpar,     Morbi  363642.0   NaN
# 4                          Old Ghuntu Road,     Morbi  363642.0   NaN
# ..                                      ...       ...       ...   ...
# 640                                Thangadh  Thangadh  363530.0   NaN
# 641                                     NaN     Morbi  363642.0   NaN
# 642                                     NaN     Morbi  363642.0   NaN
# 643       Opp. Lalpar Power House Lalpar,     Morbi  363642.0   NaN
# 644                      Jetpar Pipali Road     Morbi  363641.0   NaN
#
#            District    State  \
# 0            Rajkot  Gujarat
# 1            Rajkot  Gujarat
# 2            Rajkot  Gujarat
# 3            Rajkot  Gujarat
# 4            Rajkot  Gujarat
# ..              ...      ...
# 640  Surendra Nagar  Gujarat
# 641          Rajkot  Gujarat
# 642          Rajkot  Gujarat
# 643          Rajkot  Gujarat
# 644          Rajkot  Gujarat
#
#                                                    Tel  Fax  \
# 0                          02822-294 792 \ 98253 66773  NaN
# 1                                   02822 28 4777 / 78  NaN
# 2                     Tel: 0-98795 83540 / 98255 84540  NaN
# 3    99782 78885/9723937777 / 98254 12111 /99786 32008  NaN
# 4                         0-98254 44744 /0-97278 74500  NaN
# ..                                                 ...  ...
# 640                           02751-220205/ 9825506464  NaN
# 641                          09512024402  / 9512024403  NaN
# 642                                       02822-241316  NaN
# 643                                        98252 24926  NaN
# 644                                      0-97125 19000  NaN
#
#                        Email  Names  Capacity Unit  Upcoming Capacity  Units  \
# 0    aone.ceramics@yahoo.com    NaN       NaN  NaN                NaN    NaN
# 1       aajvetomfg@gmail.com    NaN       NaN  NaN                NaN    NaN
# 2    aarcotceramic@gmail.com    NaN       NaN  NaN                NaN    NaN
# 3         info@abcceramic.in    NaN       NaN  NaN                NaN    NaN
# 4    info@accordceramics.com    NaN       NaN  NaN                NaN    NaN
# ..                       ...    ...       ...  ...                ...    ...
# 640                      NaN    NaN       NaN  NaN                NaN    NaN
# 641    info@zarkogranito.com    NaN       NaN  NaN                NaN    NaN
# 642         info@zealtop.com    NaN       NaN  NaN                NaN    NaN
# 643    info@zedvitrified.com    NaN       NaN  NaN                NaN    NaN
# 644            info@zibon.in    NaN       NaN  NaN                NaN    NaN
#
#     Captive Power Plant Capacity
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 640                          NaN
# 641                          NaN
# 642                          NaN
# 643                          NaN
# 644                          NaN
#
# [645 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Company Name', 'AddCode', 'Add1', 'Add2', 'City', 'Pincode', 'Taluk',
#        'District', 'State', 'Tel', 'Fax', 'Email', 'Names', 'Capacity', 'Unit',
#        'Upcoming Capacity', 'Units', 'Captive Power Plant Capacity'],
#       dtype='object')

# %% [markdown]
# ### Filtering Plants

# %%
df['AddCode'].unique()
# Out:
# array(['Plant', 'Corp Office', 'Head Office'], dtype=object)

# %%
df = df[df['AddCode']=='Plant']
df.drop('AddCode',axis=1, inplace=True)
# Out:
# /tmp/ipykernel_56921/1743636810.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('AddCode',axis=1, inplace=True)

# %% [markdown]
# ### Check Duplicates

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Company Name, Add1, Add2, City, Pincode, Taluk, District, State, Tel, Fax, Email, Names, Capacity, Unit, Upcoming Capacity, Units, Captive Power Plant Capacity]
# Index: []

# %%
isid_cols = ['Company Name', 'Pincode', 'Add1', 'Add2']


df[df.duplicated(isid_cols,keep=False)]
# Out:
# Empty DataFrame
# Columns: [Company Name, Add1, Add2, City, Pincode, Taluk, District, State, Tel, Fax, Email, Names, Capacity, Unit, Upcoming Capacity, Units, Captive Power Plant Capacity]
# Index: []

# %% [markdown]
# ### Cleaning Column names and Columns

# %%
cols = df.columns

cols = [x.replace(" ", "_").lower() for x in cols]

cols
# Out:
# ['company_name',
#  'add1',
#  'add2',
#  'city',
#  'pincode',
#  'taluk',
#  'district',
#  'state',
#  'tel',
#  'fax',
#  'email',
#  'names',
#  'capacity',
#  'unit',
#  'upcoming_capacity',
#  'units',
#  'captive_power_plant_capacity']

# %%
df.columns = cols

df.rename(columns={
    "units":"upcoming_capacity_unit"
}, inplace=True)
# Out:
# /tmp/ipykernel_56921/2040414405.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={

# %%
df.drop(['tel',
 'fax',
 'email',
 'names',
 'captive_power_plant_capacity'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_56921/3798550352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['tel',

# %%
df
# Out:
#                          company_name                         add1  \
# 0               A One Ceramic Pvt Ltd        8-A National Highway,
# 1    Aajveto Manufacturing Co Pvt Ltd               Lakhdhiranagar
# 2              Aarcot Ceramic Pvt Ltd  At. Rangpar Village , Morbi
# 3                        ABC Ceramics         Morbi - Jetpar Road,
# 4             Accord Ceramics Pvt Ltd        8-A, National Highway
# ..                                ...                          ...
# 640               Zalawad Tiles Works                   Dharodiya,
# 641             Zarko Granito Pvt Ltd        Talaviya Sanala Road,
# 642           Zealtop Granito Pvt Ltd              Old Ghuntu Road
# 643             Zed Vitrified Pvt Ltd        8-A,National Highway,
# 644             Zibon Ceramic Pvt Ltd                  At Rangpar,
#
#                                        add2      city   pincode taluk  \
# 0    Lakhdhirpur Road, Behind Savio Ceramic     Morbi  363642.0   NaN
# 1                              Navagam Road     Morbi  363641.0   NaN
# 2                              Jetpar Road,     Morbi  363642.0   NaN
# 3                              At. Rangpar,     Morbi  363642.0   NaN
# 4                          Old Ghuntu Road,     Morbi  363642.0   NaN
# ..                                      ...       ...       ...   ...
# 640                                Thangadh  Thangadh  363530.0   NaN
# 641                                     NaN     Morbi  363642.0   NaN
# 642                                     NaN     Morbi  363642.0   NaN
# 643       Opp. Lalpar Power House Lalpar,     Morbi  363642.0   NaN
# 644                      Jetpar Pipali Road     Morbi  363641.0   NaN
#
#            district    state  capacity unit  upcoming_capacity  \
# 0            Rajkot  Gujarat       NaN  NaN                NaN
# 1            Rajkot  Gujarat       NaN  NaN                NaN
# 2            Rajkot  Gujarat       NaN  NaN                NaN
# 3            Rajkot  Gujarat       NaN  NaN                NaN
# 4            Rajkot  Gujarat       NaN  NaN                NaN
# ..              ...      ...       ...  ...                ...
# 640  Surendra Nagar  Gujarat       NaN  NaN                NaN
# 641          Rajkot  Gujarat       NaN  NaN                NaN
# 642          Rajkot  Gujarat       NaN  NaN                NaN
# 643          Rajkot  Gujarat       NaN  NaN                NaN
# 644          Rajkot  Gujarat       NaN  NaN                NaN
#
#      upcoming_capacity_unit
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 640                     NaN
# 641                     NaN
# 642                     NaN
# 643                     NaN
# 644                     NaN
#
# [640 rows x 12 columns]

# %%
df.to_csv(export_path, index=False)
