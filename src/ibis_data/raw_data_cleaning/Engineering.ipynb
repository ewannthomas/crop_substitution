# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
dir_path = Path.cwd().parents[2]

data_folder = dir_path.joinpath("data/ibis/raw_manually_sorted")

df_path = data_folder.joinpath("Engineering.xlsx")

export_path = dir_path.joinpath("data/ibis/interim/Engineering.csv")

# %%
df = pd.read_excel(df_path)
df
# Out:
#                                Company Name      AddCode  \
# 0                        2M Holding Pvt Ltd        Plant
# 1                        2M Holding Pvt Ltd        Plant
# 2                  4S Spintex India Pvt Ltd        Plant
# 3                         A B Tools Pvt Ltd        Plant
# 4                    A Bond Strands Pvt Ltd        Plant
# ...                                     ...          ...
# 4077  Zicom Electronic Security Systems Ltd  Corp Office
# 4078              Zimmer Automation Pvt Ltd        Plant
# 4079                            Zircast Ltd        Plant
# 4080           Zodiac Life Sciences Pvt Ltd        Plant
# 4081                          Zoloto Valves        Plant
#
#                                                    Add1  \
# 0           Survey No. 99, Kanjikode  Industrial Estate
# 1                SF.No:83/2, Site No:8 Ramakrishapuram,
# 2                      Survey No. 28/1 29/1B, Main Road
# 3                                          Plot No. 7&8
# 4                            Plot No.7, Sengundram Road
# ...                                                 ...
# 4077            Survey No.143/I Gala No F 3 First Floor
# 4078                               Gat No. 94/2, Kikvi,
# 4079                                 Nambu 37, II Phase
# 4080  Plot No. 93 , ALEAP Industrial Estate Gajulara...
# 4081             Zoloto House, 11th Mile Stone, Lambra,
#
#                                         Add2              City Pincode  \
# 0                             Pudussery East         Kanjikode  678621
# 1              Vilankurichy Road, Ganapathy,         Ganapathy  641006
# 2                                  Bhimvaram        Bhimavaram     NaN
# 3                                   Sector 3             Solan  173220
# 4                          Industrial Layout  Maraimalai Nagar  603209
# ...                                      ...               ...     ...
# 4077                 Veera Industrial Estate             Daman  396210
# 4078                                    MIDC             Kikvi  412205
# 4079                  Jigani Industrial Area            Jigani  560105
# 4080  Near Pragathi Nagar Quthbullapur(Mdl),         Hyderabad  500090
# 4081         Nakodar Rd., Jalandhar-, Punjab            Lambra  144026
#
#          Taluk     District             State  \
# 0          NaN     Palakkad            Kerala
# 1          NaN   Coimbatore        Tamil Nadu
# 2     Vatsavai      Krishna    Andhra Pradesh
# 3          NaN        Solan  Himachal Pradesh
# 4          NaN  Kanchipuram        Tamil Nadu
# ...        ...          ...               ...
# 4077       NaN          NaN       Daman & Diu
# 4078       NaN         Pune       Maharashtra
# 4079       NaN    Bangalore         Karnataka
# 4080       NaN   Rangareddy         Telangana
# 4081       NaN    Jalandhar            Punjab
#
#                                       Tel                Fax  \
# 0                      Tel: 0-99462 21223                NaN
# 1                      Tel: 0-99462 21223                NaN
# 2                      Tel: 0-98481 25730                NaN
# 3     Tel: 01792-232700 / 233051 / 233052  Fax: 01792-232423
# 4                  044-24960536, 24960833                NaN
# ...                                   ...                ...
# 4077                                  NaN                NaN
# 4078                                  NaN                NaN
# 4079            Tel: 080-7825451, 7826238       Fax: 7825463
# 4080           040-29881474, 040-29882474                NaN
# 4081  Tel: 0181-4676666 Fax: 0181-2792500                NaN
#
#                                                   Email Names Capacity  \
# 0                                                   NaN   NaN      NaN
# 1                                                   NaN   NaN      NaN
# 2                                4sspintexipl@gmail.com   NaN     8160
# 3                        Email: info@abtoolslimited.com   NaN     7200
# 4                                 info@abondstrands.com   NaN      NaN
# ...                                                 ...   ...      ...
# 4077                         Email: corporate@zicom.com   NaN      NaN
# 4078                                                NaN   NaN      NaN
# 4079                         Email: zircast@zircast.com   NaN      430
# 4080                        info@zodiaclifesciences.com   NaN      NaN
# 4081  Email: sales@zolotovalves.com/mktg@zolotovalve...   NaN      NaN
#
#           Unit Upcoming Capacity Units Captive Power Plant Capacity
# 0          NaN               NaN   NaN                          NaN
# 1          NaN               NaN   NaN                          NaN
# 2     spindles               NaN   NaN                          NaN
# 3          tpa               NaN   NaN                          NaN
# 4          NaN               NaN   NaN                          NaN
# ...        ...               ...   ...                          ...
# 4077       NaN               NaN   NaN                          NaN
# 4078       NaN               NaN   NaN                          NaN
# 4079       tpa               NaN   NaN                          NaN
# 4080       NaN               NaN   NaN                          NaN
# 4081       NaN               NaN   NaN                          NaN
#
# [4082 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Company Name', 'AddCode', 'Add1', 'Add2', 'City', 'Pincode', 'Taluk',
#        'District', 'State', 'Tel', 'Fax', 'Email', 'Names', 'Capacity', 'Unit',
#        'Upcoming Capacity', 'Units', 'Captive Power Plant Capacity'],
#       dtype='object')

# %% [markdown]
# ### Filtering Plants

# %%
df['AddCode'].unique()
# Out:
# array(['Plant', 'Branch Office', 'Sales Office', 'Corp Office',
#        'Regional Office', 'Head Office', 'Registered Office', nan,
#        'Site Office', 'Foundry Division', 'Jetty', 'Project Office'],
#       dtype=object)

# %%
df = df[df['AddCode']=='Plant']
df.drop('AddCode',axis=1, inplace=True)
# Out:
# /tmp/ipykernel_65919/1743636810.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('AddCode',axis=1, inplace=True)

# %% [markdown]
# ### Check Duplicates

# %%
df[df.duplicated(keep=False)]
# Out:
#                              Company Name  \
# 2012            Kathuria Rollmill Pvt Ltd
# 2013            Kathuria Rollmill Pvt Ltd
# 4037  Wickman Machine Tools India Pvt Ltd
# 4038  Wickman Machine Tools India Pvt Ltd
#
#                                                Add1                 Add2  \
# 2012      A-7/56-58, S.S.G.T. Road Industrial Area,                  NaN
# 2013      A-7/56-58, S.S.G.T. Road Industrial Area,                  NaN
# 4037  #851, Aggundapalli Village, Kalamangala Road,  Achattyapalli Post,
# 4038  #851, Aggundapalli Village, Kalamangala Road,  Achattyapalli Post,
#
#               City Pincode Taluk     District          State  \
# 2012     Ghaziabad  201009   NaN    Ghaziabad  Uttar Pradesh
# 2013     Ghaziabad  201009   NaN    Ghaziabad  Uttar Pradesh
# 4037  Achettipalli  635110   NaN  Krishnagiri     Tamil Nadu
# 4038  Achettipalli  635110   NaN  Krishnagiri     Tamil Nadu
#
#                                       Tel                Fax  \
# 2012  Tel: 0120 4179800, 2841851, 2841852  Fax: 0120 2841850
# 2013  Tel: 0120 4179800, 2841851, 2841852  Fax: 0120 2841850
# 4037                         04344-323308                NaN
# 4038                         04344-323308                NaN
#
#                                    Email Names Capacity Unit  \
# 2012  Email: naresh@kathuriarollmill.com   NaN      NaN  NaN
# 2013  Email: naresh@kathuriarollmill.com   NaN      NaN  NaN
# 4037            srikanth@wickmanindia.in   NaN      NaN  NaN
# 4038            srikanth@wickmanindia.in   NaN      NaN  NaN
#
#      Upcoming Capacity Units Captive Power Plant Capacity
# 2012               NaN   NaN                          NaN
# 2013               NaN   NaN                          NaN
# 4037               NaN   NaN                          NaN
# 4038               NaN   NaN                          NaN

# %%
isid_cols = ['Company Name', 'Pincode', 'Add1', 'Add2']


df[df.duplicated(isid_cols,keep=False)]
# Out:
#                              Company Name  \
# 37                       Aarti Steels Ltd
# 38                       Aarti Steels Ltd
# 39                       Aarti Steels Ltd
# 43                       Aarti Steels Ltd
# 96               Admark Polycoats Pvt Ltd
# 97               Admark Polycoats Pvt Ltd
# 1887                   Jayaswals Neco Ltd
# 1888                   Jayaswals Neco Ltd
# 1920             Jindal Steel & Power Ltd
# 1922             Jindal Steel & Power Ltd
# 1923             Jindal Steel & Power Ltd
# 1925             Jindal Steel & Power Ltd
# 2012            Kathuria Rollmill Pvt Ltd
# 2013            Kathuria Rollmill Pvt Ltd
# 2852           Purbanchal Concast Pvt Ltd
# 2853           Purbanchal Concast Pvt Ltd
# 4037  Wickman Machine Tools India Pvt Ltd
# 4038  Wickman Machine Tools India Pvt Ltd
#
#                                                Add1                   Add2  \
# 37                                      Focal Point                    NaN
# 38                 Ghantikhal , P.O . Mahakalbasta,          Via. Athgarh,
# 39                                      Focal Point                    NaN
# 43                 Ghantikhal , P.O . Mahakalbasta,          Via. Athgarh,
# 96                     Survey No. 207, Luna Village                  Padra
# 97                     Survey No. 207, Luna Village                  Padra
# 1887                          Siltara Growth Centre                Siltara
# 1888                          Siltara Growth Centre                Siltara
# 1920                      Kharsia Road, P.O. Box 16  Jindal Srips Premises
# 1922                      Kharsia Road, P.O. Box 16  Jindal Srips Premises
# 1923                      Kharsia Road, P.O. Box 16  Jindal Srips Premises
# 1925                      Kharsia Road, P.O. Box 16  Jindal Srips Premises
# 2012      A-7/56-58, S.S.G.T. Road Industrial Area,                    NaN
# 2013      A-7/56-58, S.S.G.T. Road Industrial Area,                    NaN
# 2852                  Phulbari - Ghoshpukur Bypass,     Kashiram, Siliguri
# 2853                  Phulbari - Ghoshpukur Bypass,     Kashiram, Siliguri
# 4037  #851, Aggundapalli Village, Kalamangala Road,    Achattyapalli Post,
# 4038  #851, Aggundapalli Village, Kalamangala Road,    Achattyapalli Post,
#
#                City Pincode    Taluk     District          State  \
# 37         Ludhiana  141010      NaN     Ludhiana         Punjab
# 38    Mahakalabasta  754029  Athagad      Cuttack         Odisha
# 39         Ludhiana  141010      NaN     Ludhiana         Punjab
# 43    Mahakalabasta  754029  Athagad      Cuttack         Odisha
# 96            Padra  391440      NaN     Vadodara        Gujarat
# 97            Padra  391440      NaN     Vadodara        Gujarat
# 1887        Mandhar  493111   Raipur       Raipur   Chhattisgarh
# 1888        Mandhar  493111   Raipur       Raipur   Chhattisgarh
# 1920        Raigarh  496001      NaN          NaN   Chhattisgarh
# 1922        Raigarh  496001      NaN          NaN   Chhattisgarh
# 1923        Raigarh  496001      NaN          NaN   Chhattisgarh
# 1925        Raigarh  496001      NaN          NaN   Chhattisgarh
# 2012      Ghaziabad  201009      NaN    Ghaziabad  Uttar Pradesh
# 2013      Ghaziabad  201009      NaN    Ghaziabad  Uttar Pradesh
# 2852       Siliguri  734001      NaN   Darjeeling    West Bengal
# 2853       Siliguri  734001      NaN   Darjeeling    West Bengal
# 4037   Achettipalli  635110      NaN  Krishnagiri     Tamil Nadu
# 4038   Achettipalli  635110      NaN  Krishnagiri     Tamil Nadu
#
#                                                  Tel  \
# 37                                 Tel: 0161-5244200
# 38             Tel: 0671-3061000, & 2871282 /2309285
# 39                                 Tel: 0161-3006200
# 43                         Tel: 0671-7161000/3061000
# 96    02662-302222/221586 /0-75739 95507/75739 95508
# 97                          Tel: 02662-302222/221586
# 1887                               Tel: 07721-264263
# 1888                               Tel: 07721-264263
# 1920                            Tel: 07762 227001-05
# 1922                            Tel: 07762 227001-05
# 1923                            Tel: 07762 227001-05
# 1925                            Tel: 07762 227001-05
# 2012             Tel: 0120 4179800, 2841851, 2841852
# 2013             Tel: 0120 4179800, 2841851, 2841852
# 2852                                Tel: 97751 02727
# 2853                                Tel: 97751 02727
# 4037                                    04344-323308
# 4038                                    04344-323308
#
#                                    Fax  \
# 37                        Fax: 3006250
# 38              Fax: -3061150, 2309407
# 39                        Fax: 3006250
# 43                   Fax: 0671-7161150
# 96    7573995507/7573995508/7573995509
# 97                   Fax: 02662-221587
# 1887                       Fax: 264279
# 1888                       Fax: 264279
# 1920                    Fax: 227022-23
# 1922                    Fax: 227022-23
# 1923                    Fax: 227022-23
# 1925                    Fax: 227022-23
# 2012                 Fax: 0120 2841850
# 2013                 Fax: 0120 2841850
# 2852                               NaN
# 2853                               NaN
# 4037                               NaN
# 4038                               NaN
#
#                                                   Email                 Names  \
# 37                                                  NaN  Mr. G Arora, Gen.Mgr
# 38    Email: cuttack@aartisteelsltd.com/aartisteel@s...                   NaN
# 39                                                  NaN  Mr. G Arora, Gen.Mgr
# 43    Email: cuttack@aartisteelsltd.com/aartisteel@s...                   NaN
# 96                             info@admarkpolycoats.com                   NaN
# 97                                                  NaN                   NaN
# 1887                                                NaN                   NaN
# 1888                                                NaN                   NaN
# 1920                                                NaN                   NaN
# 1922                                                NaN                   NaN
# 1923                                                NaN                   NaN
# 1925                                                NaN                   NaN
# 2012                 Email: naresh@kathuriarollmill.com                   NaN
# 2013                 Email: naresh@kathuriarollmill.com                   NaN
# 2852                          Email: pcpl2011@yahoo.com                   NaN
# 2853                          Email: pcpl2011@yahoo.com                   NaN
# 4037                           srikanth@wickmanindia.in                   NaN
# 4038                           srikanth@wickmanindia.in                   NaN
#
#      Capacity  Unit Upcoming Capacity Units Captive Power Plant Capacity
# 37      90000   tpa               NaN   NaN                          NaN
# 38      25000   tpa               NaN   NaN                          NaN
# 39      45000   tpa               NaN   NaN                          NaN
# 43        NaN   NaN              1000   tpd                 90 MW (coal)
# 96        NaN   NaN               NaN   NaN                          NaN
# 97        NaN   NaN               NaN   NaN                          NaN
# 1887   750000   tpa               NaN   NaN                        55 MW
# 1888   250000   tpa               NaN   NaN                        55 MW
# 1920  4000000   tpa               NaN   NaN                          NaN
# 1922      0.2  mtpa               NaN   NaN                          NaN
# 1923  1500000   tpa               NaN   NaN                          NaN
# 1925  1370000   tpa               NaN   NaN                          NaN
# 2012      NaN   NaN               NaN   NaN                          NaN
# 2013      NaN   NaN               NaN   NaN                          NaN
# 2852   175000   tpa               NaN   NaN                          NaN
# 2853   774000   tpa               NaN   NaN                          NaN
# 4037      NaN   NaN               NaN   NaN                          NaN
# 4038      NaN   NaN               NaN   NaN                          NaN

# %% [markdown]
# ### Cleaning Column names and Columns

# %%
cols = df.columns

cols = [x.replace(" ", "_").lower() for x in cols]

cols
# Out:
# ['company_name',
#  'add1',
#  'add2',
#  'city',
#  'pincode',
#  'taluk',
#  'district',
#  'state',
#  'tel',
#  'fax',
#  'email',
#  'names',
#  'capacity',
#  'unit',
#  'upcoming_capacity',
#  'units',
#  'captive_power_plant_capacity']

# %%
df.columns = cols

df.rename(columns={
   "units":"upcoming_capacity_unit"
}, inplace=True)
# Out:
# /tmp/ipykernel_65919/1570858624.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={

# %%
df.drop(['tel',
 'fax',
 'email',
 'names',
 'captive_power_plant_capacity'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_65919/3798550352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['tel',

# %%
df
# Out:
#                                company_name  \
# 0                        2M Holding Pvt Ltd
# 1                        2M Holding Pvt Ltd
# 2                  4S Spintex India Pvt Ltd
# 3                         A B Tools Pvt Ltd
# 4                    A Bond Strands Pvt Ltd
# ...                                     ...
# 4076  Zicom Electronic Security Systems Ltd
# 4078              Zimmer Automation Pvt Ltd
# 4079                            Zircast Ltd
# 4080           Zodiac Life Sciences Pvt Ltd
# 4081                          Zoloto Valves
#
#                                                    add1  \
# 0           Survey No. 99, Kanjikode  Industrial Estate
# 1                SF.No:83/2, Site No:8 Ramakrishapuram,
# 2                      Survey No. 28/1 29/1B, Main Road
# 3                                          Plot No. 7&8
# 4                            Plot No.7, Sengundram Road
# ...                                                 ...
# 4076                              Plot No.47, Sector -1
# 4078                               Gat No. 94/2, Kikvi,
# 4079                                 Nambu 37, II Phase
# 4080  Plot No. 93 , ALEAP Industrial Estate Gajulara...
# 4081             Zoloto House, 11th Mile Stone, Lambra,
#
#                                         add2              city pincode  \
# 0                             Pudussery East         Kanjikode  678621
# 1              Vilankurichy Road, Ganapathy,         Ganapathy  641006
# 2                                  Bhimvaram        Bhimavaram     NaN
# 3                                   Sector 3             Solan  173220
# 4                          Industrial Layout  Maraimalai Nagar  603209
# ...                                      ...               ...     ...
# 4076                                     NaN          Parwanoo  173220
# 4078                                    MIDC             Kikvi  412205
# 4079                  Jigani Industrial Area            Jigani  560105
# 4080  Near Pragathi Nagar Quthbullapur(Mdl),         Hyderabad  500090
# 4081         Nakodar Rd., Jalandhar-, Punjab            Lambra  144026
#
#          taluk     district             state capacity      unit  \
# 0          NaN     Palakkad            Kerala      NaN       NaN
# 1          NaN   Coimbatore        Tamil Nadu      NaN       NaN
# 2     Vatsavai      Krishna    Andhra Pradesh     8160  spindles
# 3          NaN        Solan  Himachal Pradesh     7200       tpa
# 4          NaN  Kanchipuram        Tamil Nadu      NaN       NaN
# ...        ...          ...               ...      ...       ...
# 4076       NaN        Solan  Himachal Pradesh      NaN       NaN
# 4078       NaN         Pune       Maharashtra      NaN       NaN
# 4079       NaN    Bangalore         Karnataka      430       tpa
# 4080       NaN   Rangareddy         Telangana      NaN       NaN
# 4081       NaN    Jalandhar            Punjab      NaN       NaN
#
#      upcoming_capacity upcoming_capacity_unit
# 0                  NaN                    NaN
# 1                  NaN                    NaN
# 2                  NaN                    NaN
# 3                  NaN                    NaN
# 4                  NaN                    NaN
# ...                ...                    ...
# 4076               NaN                    NaN
# 4078               NaN                    NaN
# 4079               NaN                    NaN
# 4080               NaN                    NaN
# 4081               NaN                    NaN
#
# [3958 rows x 12 columns]

# %%
df.to_csv(export_path, index=False)
