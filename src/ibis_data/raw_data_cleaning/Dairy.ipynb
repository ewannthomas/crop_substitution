# %%
import pandas as pd
from pathlib import Path

# %%
dir_path = Path.cwd().parents[2]

data_folder = dir_path.joinpath("data/ibis/raw_manually_sorted")

df_path = data_folder.joinpath("Dairy.xlsx")

export_path = dir_path.joinpath("data/ibis/interim/Dairy.csv")

# %%
df = pd.read_excel(df_path)
df
# Out:
#                                          Company Name AddCode  \
# 0                                  A Arunachalam & Co   Plant
# 1                          A One Milk Product Pvt Ltd   Plant
# 2    A P Dairy Development Cooperative Federation Ltd   Plant
# 3    A P Dairy Development Cooperative Federation Ltd   Plant
# 4    A P Dairy Development Cooperative Federation Ltd   Plant
# ..                                                ...     ...
# 824                       Yakult Danone India Pvt Ltd   Plant
# 825                         Yashoda Milk Food Pvt Ltd   Plant
# 826                      Yashwant Group Of Industries   Plant
# 827                          YVU Milk Producer Co Ltd   Plant
# 828                               Zeal Dairy Products   Plant
#
#                                                   Add1  \
# 0                               18/1 Sowdambiga Nagar,
# 1                186 3A, Kulayaneri, V.K. Pudur Taluk,
# 2    APDDCF Ltd.,East Godavary Milk Shed, Alcot Gar...
# 3                             Agriculture Market Yard,
# 4                              Janma Bhoomi Park Road,
# ..                                                 ...
# 824                                  402-405 Food Park
# 825                                     A-62 / A, MIDC
# 826                     Yashwant House, Plot No. B 29,
# 827                                 Thoubal Wangmataba
# 828              Survey No. 125/c-A, Ravipadu Village,
#
#                          Add2         City Pincode         Taluk  \
# 0                    Kangayam     Kangayam  638701           NaN
# 1       Tirunelveli District,        Pudur  627851           NaN
# 2           Rajahmundry Dairy  Ravulapalem  533101   Addageetala
# 3                   Kankipadu    Kankipadu  521151     Kankipadu
# 4            Narsimha Rao Pet        Eluru  534001         Eluru
# ..                        ...          ...     ...           ...
# 824       HSIDC, Phase V, Rai          Rai  131029           NaN
# 825                  Amravati    Sai Nagar  444607           NaN
# 826              MIDC Shirala      Shirala  415408           NaN
# 827                       NaN      Thoubal  795138           NaN
# 828  Narasarao Pet, Ravipadu,     Ravipadu  520013  Narasaraopet
#
#           District           State  \
# 0            Erode      Tamil Nadu
# 1      Tirunelveli      Tamil Nadu
# 2    East Godavari  Andhra Pradesh
# 3          Krishna  Andhra Pradesh
# 4    West Godavari  Andhra Pradesh
# ..             ...             ...
# 824        Sonipat         Haryana
# 825       Amravati     Maharashtra
# 826         Sangli     Maharashtra
# 827        Thoubal         Manipur
# 828         Guntur  Andhra Pradesh
#
#                                                    Tel                 Fax  \
# 0                     Tel: 0-94426 36696 /04257-220248                 NaN
# 1                                                  NaN                 NaN
# 2                        Tel: 9848160072 /0883-2442557                 NaN
# 3                      Tel: 0-9848172645/ 0866-2082405                 NaN
# 4                     Tel: 0-9247227963 /0-8812-234337                 NaN
# ..                                                 ...                 ...
# 824                                                NaN                 NaN
# 825                        Tel: 0721-2521336 / 2520057                 NaN
# 826  Tel: 02345 270 100 /86 00 009 494 /495 /496 /4...  Fax: 02345 272 699
# 827                                      0-98566 46100                 NaN
# 828                                       0-9440875124                 NaN
#
#                              Email Names  Capacity Unit  Upcoming Capacity  \
# 0    Email: aacghee@rediffmail.com   NaN       NaN  NaN                NaN
# 1                              NaN   NaN       NaN  NaN                NaN
# 2                              NaN   NaN       NaN  NaN                NaN
# 3                              NaN   NaN       NaN  NaN                NaN
# 4                              NaN   NaN       NaN  NaN                NaN
# ..                             ...   ...       ...  ...                ...
# 824                            NaN   NaN       NaN  NaN                NaN
# 825   Email: info@yashodafoods.com   NaN       NaN  NaN                NaN
# 826  Email: info@yashwantgroup.com   NaN       NaN  NaN                NaN
# 827              yvumilk@yvu.co.in   NaN       NaN  NaN                NaN
# 828                            NaN   NaN       NaN  NaN                NaN
#
#     Units Captive Power Plant Capacity
# 0     NaN                          NaN
# 1     NaN                          NaN
# 2     NaN                          NaN
# 3     NaN                          NaN
# 4     NaN                          NaN
# ..    ...                          ...
# 824   NaN                          NaN
# 825   NaN                          NaN
# 826   NaN                          NaN
# 827   NaN                          NaN
# 828   NaN                          NaN
#
# [829 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Company Name', 'AddCode', 'Add1', 'Add2', 'City', 'Pincode', 'Taluk',
#        'District', 'State', 'Tel', 'Fax', 'Email', 'Names', 'Capacity', 'Unit',
#        'Upcoming Capacity', 'Units', 'Captive Power Plant Capacity'],
#       dtype='object')

# %% [markdown]
# ### Filtering Plants

# %%
df['AddCode'].unique()
# Out:
# array(['Plant', 'Corp Office', 'Branch Office'], dtype=object)

# %%
df = df[df['AddCode']=='Plant']
df.drop('AddCode',axis=1, inplace=True)
# Out:
# /tmp/ipykernel_57795/1743636810.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('AddCode',axis=1, inplace=True)

# %% [markdown]
# ### Check Duplicates

# %% [markdown]
# In paper directory there is 1 line by line duplicates. Removing these.

# %%
df[df.duplicated(keep=False)]
# Out:
#             Company Name        Add1 Add2        City Pincode Taluk District  \
# 473  Model Dairy Pvt Ltd  Nidamanuru  NaN  Vijayawada  521104   NaN  Krishna
# 474  Model Dairy Pvt Ltd  Nidamanuru  NaN  Vijayawada  521104   NaN  Krishna
#
#               State                                    Tel                Fax  \
# 473  Andhra Pradesh  Tel: 9666924999 /0866-2842777/2842396  Fax: 0866-2842111
# 474  Andhra Pradesh  Tel: 9666924999 /0866-2842777/2842396  Fax: 0866-2842111
#
#     Email Names  Capacity Unit  Upcoming Capacity Units  \
# 473   NaN   NaN       NaN  NaN                NaN   NaN
# 474   NaN   NaN       NaN  NaN                NaN   NaN
#
#     Captive Power Plant Capacity
# 473                          NaN
# 474                          NaN

# %%
isid_cols = ['Company Name', 'Pincode', 'Add1', 'Add2']


df[df.duplicated(isid_cols,keep=False)]
# Out:
#                  Company Name              Add1                      Add2  \
# 55   Angad Milk Foods Pvt Ltd  Village Panjwad,  Chabhal Bhikhiwind Road,
# 56   Angad Milk Foods Pvt Ltd  Village Panjwad,  Chabhal Bhikhiwind Road,
# 473       Model Dairy Pvt Ltd        Nidamanuru                       NaN
# 474       Model Dairy Pvt Ltd        Nidamanuru                       NaN
#
#            City Pincode Taluk  District           State  \
# 55      Panjwar  143301   NaN  Amritsar          Punjab
# 56      Panjwar  143301   NaN  Amritsar          Punjab
# 473  Vijayawada  521104   NaN   Krishna  Andhra Pradesh
# 474  Vijayawada  521104   NaN   Krishna  Andhra Pradesh
#
#                                        Tel                Fax  \
# 55                           0-98888 72902                NaN
# 56                           0-98888 72902                NaN
# 473  Tel: 9666924999 /0866-2842777/2842396  Fax: 0866-2842111
# 474  Tel: 9666924999 /0866-2842777/2842396  Fax: 0866-2842111
#
#                        Email Names  Capacity      Unit  Upcoming Capacity  \
# 55   angadmilkfood@gmail.com   NaN       NaN       NaN                NaN
# 56                       NaN   NaN       2.0  lakh lpd                NaN
# 473                      NaN   NaN       NaN       NaN                NaN
# 474                      NaN   NaN       NaN       NaN                NaN
#
#     Units Captive Power Plant Capacity
# 55    NaN                          NaN
# 56    NaN                          NaN
# 473   NaN                          NaN
# 474   NaN                          NaN

# %% [markdown]
# ### Cleaning Column names and Columns

# %%
cols = df.columns

cols = [x.replace(" ", "_").lower() for x in cols]

cols
# Out:
# ['company_name',
#  'add1',
#  'add2',
#  'city',
#  'pincode',
#  'taluk',
#  'district',
#  'state',
#  'tel',
#  'fax',
#  'email',
#  'names',
#  'capacity',
#  'unit',
#  'upcoming_capacity',
#  'units',
#  'captive_power_plant_capacity']

# %%
df.columns = cols

df.rename(columns={
    "unit":"units",
    "units":"upcoming_capacity_unit"
}, inplace=True)
# Out:
# /tmp/ipykernel_57795/2080986438.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={

# %%
df.drop(['tel',
 'fax',
 'email',
 'names',
 'captive_power_plant_capacity'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_57795/3798550352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['tel',

# %%
df
# Out:
#                                          company_name  \
# 0                                  A Arunachalam & Co
# 1                          A One Milk Product Pvt Ltd
# 2    A P Dairy Development Cooperative Federation Ltd
# 3    A P Dairy Development Cooperative Federation Ltd
# 4    A P Dairy Development Cooperative Federation Ltd
# ..                                                ...
# 824                       Yakult Danone India Pvt Ltd
# 825                         Yashoda Milk Food Pvt Ltd
# 826                      Yashwant Group Of Industries
# 827                          YVU Milk Producer Co Ltd
# 828                               Zeal Dairy Products
#
#                                                   add1  \
# 0                               18/1 Sowdambiga Nagar,
# 1                186 3A, Kulayaneri, V.K. Pudur Taluk,
# 2    APDDCF Ltd.,East Godavary Milk Shed, Alcot Gar...
# 3                             Agriculture Market Yard,
# 4                              Janma Bhoomi Park Road,
# ..                                                 ...
# 824                                  402-405 Food Park
# 825                                     A-62 / A, MIDC
# 826                     Yashwant House, Plot No. B 29,
# 827                                 Thoubal Wangmataba
# 828              Survey No. 125/c-A, Ravipadu Village,
#
#                          add2         city pincode         taluk  \
# 0                    Kangayam     Kangayam  638701           NaN
# 1       Tirunelveli District,        Pudur  627851           NaN
# 2           Rajahmundry Dairy  Ravulapalem  533101   Addageetala
# 3                   Kankipadu    Kankipadu  521151     Kankipadu
# 4            Narsimha Rao Pet        Eluru  534001         Eluru
# ..                        ...          ...     ...           ...
# 824       HSIDC, Phase V, Rai          Rai  131029           NaN
# 825                  Amravati    Sai Nagar  444607           NaN
# 826              MIDC Shirala      Shirala  415408           NaN
# 827                       NaN      Thoubal  795138           NaN
# 828  Narasarao Pet, Ravipadu,     Ravipadu  520013  Narasaraopet
#
#           district           state  capacity units  upcoming_capacity  \
# 0            Erode      Tamil Nadu       NaN   NaN                NaN
# 1      Tirunelveli      Tamil Nadu       NaN   NaN                NaN
# 2    East Godavari  Andhra Pradesh       NaN   NaN                NaN
# 3          Krishna  Andhra Pradesh       NaN   NaN                NaN
# 4    West Godavari  Andhra Pradesh       NaN   NaN                NaN
# ..             ...             ...       ...   ...                ...
# 824        Sonipat         Haryana       NaN   NaN                NaN
# 825       Amravati     Maharashtra       NaN   NaN                NaN
# 826         Sangli     Maharashtra       NaN   NaN                NaN
# 827        Thoubal         Manipur       NaN   NaN                NaN
# 828         Guntur  Andhra Pradesh       NaN   NaN                NaN
#
#     upcoming_capacity_unit
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ..                     ...
# 824                    NaN
# 825                    NaN
# 826                    NaN
# 827                    NaN
# 828                    NaN
#
# [815 rows x 12 columns]

# %%
df.to_csv(export_path, index=False)
