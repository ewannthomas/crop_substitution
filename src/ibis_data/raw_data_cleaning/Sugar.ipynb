# %%
import pandas as pd
from pathlib import Path

# %%
dir_path = Path.cwd().parents[2]

data_folder = dir_path.joinpath("data/ibis/raw_manually_sorted")

df_path = data_folder.joinpath("Sugar.xlsx")

export_path = dir_path.joinpath("data/ibis/interim/Sugar.csv")

# %%
df = pd.read_excel(df_path)
df
# Out:
#                             Company Name AddCode  \
# 0                         A B Sugars Ltd   Plant
# 1                         A B Sugars Ltd   Plant
# 2                         A B Sugars Ltd   Plant
# 3                         A B Sugars Ltd   Plant
# 4                         A B Sugars Ltd   Plant
# ...                                  ...     ...
# 1385                        Yeshwant SSK   Plant
# 1386  Yeshwantrao Mohite Krishna SSK Ltd   Plant
# 1387      Yogeshwar Sugar Industries Ltd   Plant
# 1388      Yogeshwar Sugar Industries Ltd   Plant
# 1389               Zira Coop Sugar Mills   Plant
#
#                                           Add1  \
# 0                             Adempura Village
# 1     Bijnor, Near Railway Station Nagina Road
# 2                                  Bulandshahr
# 3                                Chadha Estate
# 4                                Chadha Estate
# ...                                        ...
# 1385                                  Khanapur
# 1386                                   Rethare
# 1387                                Laxminagar
# 1388                                Laxminagar
# 1389                                      Zira
#
#                                 Add2            City   Pincode     Taluk  \
# 0               Ashram, Atrauli Road         Aligarh  202002.0       NaN
# 1                                NaN          Bijnor  246701.0       NaN
# 2                                NaN     Bulandshahr  203001.0       NaN
# 3                P.O. Mandi Dhanaura  Dhanaura Aheer  244231.0    Amroha
# 4     Village Malaysia, P.O. Dhanura   Chadha Estate       NaN       NaN
# ...                              ...             ...       ...       ...
# 1385                             NaN        Khanapur       NaN  Khanapur
# 1386                     Budruk P.O.     Rethare kh.  415108.0     Karad
# 1387                           Limba     Limba Tanda  431541.0    Pathri
# 1388                           Limba     Limba Tanda  431541.0    Pathri
# 1389                     Ritaul Rohi        Zira Nau  142047.0      Zira
#
#                  District          State                                Tel  \
# 0                 Aligarh  Uttar Pradesh          Tel: 0571-2750600/2750666
# 1                  Bijnor  Uttar Pradesh                  Tel: 01342-252035
# 2             Bulandshahr  Uttar Pradesh                 Tel: 0-80579 11415
# 3     Jyotiba Phule Nagar  Uttar Pradesh  Tel: 05924-273104, 273105, 273046
# 4     Jyotiba Phule Nagar  Uttar Pradesh                  Tel: 05924-273104
# ...                   ...            ...                                ...
# 1385               Sangli    Maharashtra   Tel: 020-26913282 TO 84,26913387
# 1386               Satara    Maharashtra        Tel: 02164-266222 TO 266225
# 1387             Parbhani    Maharashtra          Tel: 02451-261507 /261527
# 1388             Parbhani    Maharashtra          Tel: 02451-261507 /261527
# 1389            Ferozepur         Punjab             Tel: 01681-50120/50154
#
#                     Fax                                              Email  \
# 0                   NaN                                                NaN
# 1                   NaN                   Email: cgm.bij@waveindustries.in
# 2                   NaN                                                NaN
# 3     Fax: 05924-273047                  Email: chadhagroup@rediffmail.com
# 4                   NaN                       Email: capi@chadhasugars.com
# ...                 ...                                                ...
# 1385  Fax: 020-26913281                                                NaN
# 1386  Fax: 02164-266226  Email: ksskrethare@sancharnet.in /ymkrishnassk...
# 1387  Fax: 02451-261537             Email: yogeshwari_sugar@rediffmail.com
# 1388  Fax: 02451-261537             Email: yogeshwari_sugar@rediffmail.com
# 1389                NaN                                                NaN
#
#                                                   Names Capacity Unit  \
# 0                                                   NaN      NaN  NaN
# 1     Plant Make : TRIVENI, WIL /Milling Plants : 1 ...     3500  tcd
# 2     Plant Make : THYSSEN KRUPP /Milling Plants : 1...     3500  tcd
# 3                                                   NaN    72000  tpa
# 4     Plant Make : TRIVENI /Milling Plants : 2 sets ...     8300  tcd
# ...                                                 ...      ...  ...
# 1385                                                NaN      NaN  NaN
# 1386  Plant Make : WIL, KCP, BW, NHEC/Milling Plants...     7200  tcd
# 1387                                                NaN      NaN  NaN
# 1388  Plant Make : THYSSEN KRUPP /Milling Plants : Z...     1000  tcd
# 1389                                                NaN     2500  tcd
#
#      Upcoming Capacity Units Captive Power Plant Capacity
# 0                   58  klpd    2.0 MW (Cogen)(Upcoming|)
# 1                  NaN   NaN                          NaN
# 2                  NaN   NaN                          NaN
# 3                  NaN   NaN                          NaN
# 4                  NaN   NaN                          NaN
# ...                ...   ...                          ...
# 1385               NaN   NaN                          NaN
# 1386               NaN   NaN                         16MW
# 1387               110  klpd               1.5 MW (Cogen)
# 1388               NaN   NaN                    12 MW (U)
# 1389               NaN   NaN                          NaN
#
# [1390 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Company Name', 'AddCode', 'Add1', 'Add2', 'City', 'Pincode', 'Taluk',
#        'District', 'State', 'Tel', 'Fax', 'Email', 'Names', 'Capacity', 'Unit',
#        'Upcoming Capacity', 'Units', 'Captive Power Plant Capacity'],
#       dtype='object')

# %% [markdown]
# ### Filtering Plants

# %%
df['AddCode'].unique()
# Out:
# array(['Plant', 'Branch Office', 'Corp Office', 'plant'], dtype=object)

# %%
df = df[df['AddCode'].isin(['Plant', 'plant'])]
df.drop('AddCode',axis=1, inplace=True)
# Out:
# /tmp/ipykernel_82137/786839252.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('AddCode',axis=1, inplace=True)

# %% [markdown]
# ### Check Duplicates

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Company Name, Add1, Add2, City, Pincode, Taluk, District, State, Tel, Fax, Email, Names, Capacity, Unit, Upcoming Capacity, Units, Captive Power Plant Capacity]
# Index: []

# %%
isid_cols = ['Company Name', 'Pincode', 'Add1', 'Add2']


df[df.duplicated(isid_cols,keep=False)]
# Out:
#                           Company Name                          Add1  \
# 4                       A B Sugars Ltd                 Chadha Estate
# 5                       A B Sugars Ltd                 Chadha Estate
# 9                   Adinath Sugars Ltd               Plot No. 150/6,
# 10                  Adinath Sugars Ltd               Plot No. 150/6,
# 13                      Agasti SSK Ltd                   Akole Taluk
# ...                                ...                           ...
# 1372                   Vitthal SSK Ltd  Ghursale Captive Power Plant
# 1382  Yedeshwari Agro Products Pvt Ltd             Anandgaon Village
# 1383  Yedeshwari Agro Products Pvt Ltd             Anandgaon Village
# 1387    Yogeshwar Sugar Industries Ltd                    Laxminagar
# 1388    Yogeshwar Sugar Industries Ltd                    Laxminagar
#
#                                 Add2           City   Pincode      Taluk  \
# 4     Village Malaysia, P.O. Dhanura  Chadha Estate       NaN        NaN
# 5     Village Malaysia, P.O. Dhanura  Chadha Estate       NaN        NaN
# 9       Gokak Road, Harugeri, Raybag       Harugeri  591220.0        NaN
# 10      Gokak Road, Harugeri, Raybag       Harugeri  591220.0        NaN
# 13           Ahmednagar, Maharashtra          Akole  422621.0        NaN
# ...                              ...            ...       ...        ...
# 1372                 Pandarpur Taluk        Gursale       NaN  Malshiras
# 1382                      Kaij Taluk      Anandgaon  431131.0        NaN
# 1383                      Kaij Taluk      Anandgaon  431131.0        NaN
# 1387                           Limba    Limba Tanda  431541.0     Pathri
# 1388                           Limba    Limba Tanda  431541.0     Pathri
#
#                  District          State  \
# 4     Jyotiba Phule Nagar  Uttar Pradesh
# 5     Jyotiba Phule Nagar  Uttar Pradesh
# 9                 Belgaum      Karnataka
# 10                Belgaum      Karnataka
# 13             Ahmednagar    Maharashtra
# ...                   ...            ...
# 1372              Solapur    Maharashtra
# 1382                 Beed    Maharashtra
# 1383                 Beed    Maharashtra
# 1387             Parbhani    Maharashtra
# 1388             Parbhani    Maharashtra
#
#                                            Tel                  Fax  \
# 4                            Tel: 05924-273104                  NaN
# 5                            Tel: 05924-273104                  NaN
# 9           Tel: 0-99022 30127 / 0-94486 92716                  NaN
# 10                Tel: 9902230127 / 9448692716                  NaN
# 13                 Tel: 02424 - 222714 / 22775  Fax: 02424 - 223283
# ...                                        ...                  ...
# 1372  Tel: 02183 233005, 233056,2233075,233500    Fax: 02186-249625
# 1382             Tel: 02445-251316 /8411974301                  NaN
# 1383             Tel: 02445-251316 /8411974301                  NaN
# 1387                 Tel: 02451-261507 /261527    Fax: 02451-261537
# 1388                 Tel: 02451-261507 /261527    Fax: 02451-261537
#
#                                        Email  \
# 4               Email: capi@chadhasugars.com
# 5               Email: capi@chadhasugars.com
# 9                                        NaN
# 10                                       NaN
# 13                                       NaN
# ...                                      ...
# 1372       Email: shrivitthalsugar@yahoo.com
# 1382                 Email: yapltd@gmail.com
# 1383                 Email: yapltd@gmail.com
# 1387  Email: yogeshwari_sugar@rediffmail.com
# 1388  Email: yogeshwari_sugar@rediffmail.com
#
#                                                   Names Capacity  Unit  \
# 4     Plant Make : TRIVENI /Milling Plants : 2 sets ...     8300   tcd
# 5                                                   NaN      NaN   NaN
# 9                                                   NaN     4500   tcd
# 10                                                  NaN      NaN   NaN
# 13                                                  NaN     2500   tcd
# ...                                                 ...      ...   ...
# 1372  Plant Make : BW, NHEC, ULKA/Milling Plants : B...       10    MW
# 1382                                                NaN       45  klpd
# 1383  Plant Make : MERU /Milling Plants : 1 Set Kniv...     3500   tcd
# 1387                                                NaN      NaN   NaN
# 1388  Plant Make : THYSSEN KRUPP /Milling Plants : Z...     1000   tcd
#
#      Upcoming Capacity Units Captive Power Plant Capacity
# 4                  NaN   NaN                          NaN
# 5                  180  klpd                         30MW
# 9                  NaN   NaN                        10 MW
# 10                  30  klpd                          NaN
# 13                 NaN   NaN                          NaN
# ...                ...   ...                          ...
# 1372                19    MW                          NaN
# 1382                65  klpd                          NaN
# 1383               NaN   NaN                          NaN
# 1387               110  klpd               1.5 MW (Cogen)
# 1388               NaN   NaN                    12 MW (U)
#
# [240 rows x 17 columns]

# %% [markdown]
# ### Cleaning Column names and Columns

# %%
cols = df.columns

cols = [x.replace(" ", "_").lower() for x in cols]

cols
# Out:
# ['company_name',
#  'add1',
#  'add2',
#  'city',
#  'pincode',
#  'taluk',
#  'district',
#  'state',
#  'tel',
#  'fax',
#  'email',
#  'names',
#  'capacity',
#  'unit',
#  'upcoming_capacity',
#  'units',
#  'captive_power_plant_capacity']

# %%
df.columns = cols

df.rename(columns={
    "unit":"upcoming_capacity_unit"
}, inplace=True)
# Out:
# /tmp/ipykernel_82137/493518851.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={

# %%
df.drop(['tel',
 'fax',
 'email',
 'names',
 ], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_82137/1277888338.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['tel',

# %%
df
# Out:
#                             company_name  \
# 0                         A B Sugars Ltd
# 1                         A B Sugars Ltd
# 2                         A B Sugars Ltd
# 3                         A B Sugars Ltd
# 4                         A B Sugars Ltd
# ...                                  ...
# 1385                        Yeshwant SSK
# 1386  Yeshwantrao Mohite Krishna SSK Ltd
# 1387      Yogeshwar Sugar Industries Ltd
# 1388      Yogeshwar Sugar Industries Ltd
# 1389               Zira Coop Sugar Mills
#
#                                           add1  \
# 0                             Adempura Village
# 1     Bijnor, Near Railway Station Nagina Road
# 2                                  Bulandshahr
# 3                                Chadha Estate
# 4                                Chadha Estate
# ...                                        ...
# 1385                                  Khanapur
# 1386                                   Rethare
# 1387                                Laxminagar
# 1388                                Laxminagar
# 1389                                      Zira
#
#                                 add2            city   pincode     taluk  \
# 0               Ashram, Atrauli Road         Aligarh  202002.0       NaN
# 1                                NaN          Bijnor  246701.0       NaN
# 2                                NaN     Bulandshahr  203001.0       NaN
# 3                P.O. Mandi Dhanaura  Dhanaura Aheer  244231.0    Amroha
# 4     Village Malaysia, P.O. Dhanura   Chadha Estate       NaN       NaN
# ...                              ...             ...       ...       ...
# 1385                             NaN        Khanapur       NaN  Khanapur
# 1386                     Budruk P.O.     Rethare kh.  415108.0     Karad
# 1387                           Limba     Limba Tanda  431541.0    Pathri
# 1388                           Limba     Limba Tanda  431541.0    Pathri
# 1389                     Ritaul Rohi        Zira Nau  142047.0      Zira
#
#                  district          state capacity upcoming_capacity_unit  \
# 0                 Aligarh  Uttar Pradesh      NaN                    NaN
# 1                  Bijnor  Uttar Pradesh     3500                    tcd
# 2             Bulandshahr  Uttar Pradesh     3500                    tcd
# 3     Jyotiba Phule Nagar  Uttar Pradesh    72000                    tpa
# 4     Jyotiba Phule Nagar  Uttar Pradesh     8300                    tcd
# ...                   ...            ...      ...                    ...
# 1385               Sangli    Maharashtra      NaN                    NaN
# 1386               Satara    Maharashtra     7200                    tcd
# 1387             Parbhani    Maharashtra      NaN                    NaN
# 1388             Parbhani    Maharashtra     1000                    tcd
# 1389            Ferozepur         Punjab     2500                    tcd
#
#      upcoming_capacity units captive_power_plant_capacity
# 0                   58  klpd    2.0 MW (Cogen)(Upcoming|)
# 1                  NaN   NaN                          NaN
# 2                  NaN   NaN                          NaN
# 3                  NaN   NaN                          NaN
# 4                  NaN   NaN                          NaN
# ...                ...   ...                          ...
# 1385               NaN   NaN                          NaN
# 1386               NaN   NaN                         16MW
# 1387               110  klpd               1.5 MW (Cogen)
# 1388               NaN   NaN                    12 MW (U)
# 1389               NaN   NaN                          NaN
#
# [1363 rows x 13 columns]

# %%
df.to_csv(export_path, index=False)
