# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
dir_path = Path.cwd().parents[2]

data_folder = dir_path.joinpath("data/ibis/raw_manually_sorted")

df_path = data_folder.joinpath("Paper.xlsx")

export_path = dir_path.joinpath("data/ibis/interim/Paper.csv")

# %%
df = pd.read_excel(df_path)
df
# Out:
#                           Company Name        AddCode  \
# 0      Aadharshree Paper Mills Pvt Ltd          Plant
# 1    Aaditiya Aswin Paper Mill Pvt Ltd          Plant
# 2    Aaditiya Aswin Paper Mill Pvt Ltd  Branch Office
# 3    Aaditiya Aswin Paper Mill Pvt Ltd  Branch Office
# 4       Aaditya Kraft & Papers Pvt Ltd          Plant
# ..                                 ...            ...
# 913                    Yash Papers Ltd          Plant
# 914             York Cellulose Pvt Ltd          Plant
# 915          Zielen Industries Pvt Ltd          Plant
# 916           Zion Paper Mills Pvt Ltd          Plant
# 917              Zuberi Fibres Pvt Ltd          Plant
#
#                                  Add1  \
# 0              Manglore, Deoband Road
# 1       SF No:65, Ikkaraithathapally,
# 2                 25/1380, Marar Road
# 3      Door No.33,Tatabad 2nd Street,
# 4                Sauria, Gurudijhatia
# ..                                ...
# 913                       Yash Nagar,
# 914              Plot No. 215, HSIIDC
# 915   Survey No: - 459 Mazara Chokdi,
# 916   No. 51/5 & 6, Kaduvettipalayam,
# 917  UPSIDC, Chherat Industrial Area,
#
#                                                   Add2                City  \
# 0                             Haridwar, Mundet Village            Manglour
# 1                         Mothamangalam, Bhavanisagar,  Ikkaraithathapalli
# 2                                             Thrissur            Thrissur
# 3                                   Sivanandha Colony,             Tatabad
# 4                                                  NaN              Sauria
# ..                                                 ...                 ...
# 913                                      Darshan Nagar       Darshan Nagar
# 914                         Industrial Estate Manakpur         Yamunanagar
# 915  B/H. Sabar College, Tajpur (Oran) Chiloda, Him...              Tajpur
# 916                              Karumathampattty Post     Karumathampatti
# 917                                  Anoophshahr Road,             Aligarh
#
#       Pincode         Taluk      District          State  \
# 0    247656.0           NaN      Haridwar    Uttaranchal
# 1    638451.0           NaN         Erode     Tamil Nadu
# 2    680001.0           NaN      Thrissur         Kerala
# 3    641012.0           NaN    Coimbatore     Tamil Nadu
# 4    754029.0  Gurudijhatia       Cuttack         Odisha
# ..        ...           ...           ...            ...
# 913  224135.0           NaN      Faizabad  Uttar Pradesh
# 914  135001.0           NaN  Yamuna Nagar        Haryana
# 915  383205.0           NaN   Sabarkantha        Gujarat
# 916  641659.0           NaN    Coimbatore     Tamil Nadu
# 917  202002.0           NaN       Aligarh  Uttar Pradesh
#
#                                          Tel                Fax  \
# 0                                        NaN                NaN
# 1    Tel: 0422-2490091, 2490092/04295 292493                NaN
# 2                          Tel: 0487-2427515                NaN
# 3                  Tel: 0422 2430091/2440091                NaN
# 4          Tel: 0-98615 40090 /0-73775 31977                NaN
# ..                                       ...                ...
# 913                Tel: 05278 326611 /326612  Fax: 05278 258062
# 914                         Tel: 99966 93330                NaN
# 915                             0-9377459202                NaN
# 916               0422-288072 /0-96777 20599                NaN
# 917              Tel: 0-7300700751 / 52 / 53                NaN
#
#                                      Email Names Capacity Units  \
# 0                                      NaN   NaN    23100   tpa
# 1            Email: aapm.general@gmail.com   NaN    18000   tpa
# 2                Email: aapm.tcr@gmail.com   NaN      NaN   NaN
# 3                                      NaN   NaN      NaN   NaN
# 4                                      NaN   NaN      NaN   NaN
# ..                                     ...   ...      ...   ...
# 913            Email: info@yash-papers.com   NaN      NaN   NaN
# 914                                    NaN   NaN      NaN   NaN
# 915                    zip_crb@yahoo.co.in   NaN      NaN   NaN
# 916                                    NaN   NaN      NaN   NaN
# 917  Email: aligarh.zuberifibres@gmail.com   NaN      NaN   NaN
#
#     Upcoming Capacity Units.1 Captive Power Plant Capacity
# 0                 NaN     NaN                          NaN
# 1                 NaN     NaN                          NaN
# 2                 NaN     NaN                          NaN
# 3                 NaN     NaN                          NaN
# 4                 NaN     NaN                          NaN
# ..                ...     ...                          ...
# 913               NaN     NaN                      12.5 MW
# 914               NaN     NaN                          NaN
# 915               NaN     NaN                          NaN
# 916               NaN     NaN                          NaN
# 917               NaN     NaN                          NaN
#
# [918 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Company Name', 'AddCode', 'Add1', 'Add2', 'City', 'Pincode', 'Taluk',
#        'District', 'State', 'Tel', 'Fax', 'Email', 'Names', 'Capacity',
#        'Units', 'Upcoming Capacity', 'Units.1',
#        'Captive Power Plant Capacity'],
#       dtype='object')

# %% [markdown]
# ### Filtering Plants

# %%
df['AddCode'].unique()
# Out:
# array(['Plant', 'Branch Office', 'HO/Corp Office', 'Corp Office',
#        'Head Office'], dtype=object)

# %%
df = df[df['AddCode']=='Plant']
df.drop('AddCode',axis=1, inplace=True)
# Out:
# /tmp/ipykernel_5119/1743636810.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('AddCode',axis=1, inplace=True)

# %% [markdown]
# ### Check Duplicates

# %% [markdown]
# In paper directory there are 10 line by line duplicates. Removing these.

# %%
df[df.duplicated(keep=False)]
# Out:
#                            Company Name                              Add1  \
# 99            Bedse Paper Mills Pvt Ltd                   F /32, M I D C,
# 100           Bedse Paper Mills Pvt Ltd                   F /32, M I D C,
# 130            Borkar Packaging Pvt Ltd  341/5A, Bharat Indl. Estate Area
# 133            Borkar Packaging Pvt Ltd  341/5A, Bharat Indl. Estate Area
# 209        East India Packaging Pvt Ltd       6, 2nd Floor, Mangore Lane,
# 210        East India Packaging Pvt Ltd       6, 2nd Floor, Mangore Lane,
# 740           Speciality Papers Pvt Ltd                    Morai Village,
# 744           Speciality Papers Pvt Ltd                    Morai Village,
# 823  Supreme Coated Board Mills Pvt Ltd              Vembakottai Village,
# 824  Supreme Coated Board Mills Pvt Ltd              Vembakottai Village,
#
#                               Add2        City   Pincode Taluk      District  \
# 99                    Chilkalthana  Aurangabad  431210.0   NaN    Aurangabad
# 100                   Chilkalthana  Aurangabad  431210.0   NaN    Aurangabad
# 130        Bhimpore Village, Daman       Daman  396210.0   NaN           NaN
# 133        Bhimpore Village, Daman       Daman  396210.0   NaN           NaN
# 209  Near Calcutta Tramway Company     Kolkata  700001.0   NaN           NaN
# 210  Near Calcutta Tramway Company     Kolkata  700001.0   NaN           NaN
# 740         National Highway No.8,        Vapi  396191.0   NaN        Valsad
# 744         National Highway No.8,        Vapi  396191.0   NaN        Valsad
# 823                       Sivakasi    Sivakasi  626123.0   NaN  Virudhunagar
# 824                       Sivakasi    Sivakasi  626123.0   NaN  Virudhunagar
#
#            State                     Tel           Fax  \
# 99   Maharashtra  0240 248 2633/248 3131           NaN
# 100  Maharashtra  0240 248 2633/248 3131           NaN
# 130  Daman & Diu         0260 - 661 8700           NaN
# 133  Daman & Diu         0260 - 661 8700           NaN
# 209  West Bengal           0-98303 19277           NaN
# 210  West Bengal           0-98303 19277           NaN
# 740      Gujarat       0260 2437159 / 60           NaN
# 744      Gujarat       0260 2437159 / 60           NaN
# 823   Tamil Nadu    04562 284022, 284155  04562 284011
# 824   Tamil Nadu    04562 284022, 284155  04562 284011
#
#                                          Email Names Capacity Units  \
# 99                      bedsepaper@yahoo.co.in   NaN      NaN   NaN
# 100                     bedsepaper@yahoo.co.in   NaN      NaN   NaN
# 130                       bppld@borkarpack.com   NaN      NaN   NaN
# 133                       bppld@borkarpack.com   NaN      NaN   NaN
# 209                      eipplhaldia@gmail.com   NaN      NaN   NaN
# 210                      eipplhaldia@gmail.com   NaN      NaN   NaN
# 740          speciality@reliablepaperindia.com   NaN      NaN   NaN
# 744          speciality@reliablepaperindia.com   NaN      NaN   NaN
# 823  sales@scbmpl.com, sales@supremegroups.org   NaN      NaN   NaN
# 824  sales@scbmpl.com, sales@supremegroups.org   NaN      NaN   NaN
#
#     Upcoming Capacity Units.1 Captive Power Plant Capacity
# 99                NaN     NaN                          NaN
# 100               NaN     NaN                          NaN
# 130               NaN     NaN                          NaN
# 133               NaN     NaN                          NaN
# 209               NaN     NaN                          NaN
# 210               NaN     NaN                          NaN
# 740               NaN     NaN                          NaN
# 744               NaN     NaN                          NaN
# 823               NaN     NaN                          NaN
# 824               NaN     NaN                          NaN

# %%
isid_cols = ['Company Name', 'Pincode', 'Add1', 'Add2']


df[df.duplicated(isid_cols,keep=False)]
# Out:
#                                   Company Name  \
# 99                   Bedse Paper Mills Pvt Ltd
# 100                  Bedse Paper Mills Pvt Ltd
# 130                   Borkar Packaging Pvt Ltd
# 133                   Borkar Packaging Pvt Ltd
# 209               East India Packaging Pvt Ltd
# 210               East India Packaging Pvt Ltd
# 248                       Girija Craft Pvt Ltd
# 249                       Girija Craft Pvt Ltd
# 273  Hanuman Agro Industries Ltd (Paper Mills)
# 274  Hanuman Agro Industries Ltd (Paper Mills)
# 680            Shree Bhageswari Papers Pvt Ltd
# 681            Shree Bhageswari Papers Pvt Ltd
# 740                  Speciality Papers Pvt Ltd
# 744                  Speciality Papers Pvt Ltd
# 805                   Subhodaya Paper Products
# 806                   Subhodaya Paper Products
# 823         Supreme Coated Board Mills Pvt Ltd
# 824         Supreme Coated Board Mills Pvt Ltd
#
#                                       Add1  \
# 99                         F /32, M I D C,
# 100                        F /32, M I D C,
# 130       341/5A, Bharat Indl. Estate Area
# 133       341/5A, Bharat Indl. Estate Area
# 209            6, 2nd Floor, Mangore Lane,
# 210            6, 2nd Floor, Mangore Lane,
# 248         No. 97 & 98, Solapur Compound,
# 249         No. 97 & 98, Solapur Compound,
# 273    Vill. : Paragaon,  Nawapara - Rajim
# 274    Vill. : Paragaon,  Nawapara - Rajim
# 680                   9th Km., Bhopa Road,
# 681                   9th Km., Bhopa Road,
# 740                         Morai Village,
# 744                         Morai Village,
# 805  Survey No:187/22, Peddipalem Village,
# 806  Survey No:187/22, Peddipalem Village,
# 823                   Vembakottai Village,
# 824                   Vembakottai Village,
#
#                                             Add2        City   Pincode  \
# 99                                  Chilkalthana  Aurangabad  431210.0
# 100                                 Chilkalthana  Aurangabad  431210.0
# 130                      Bhimpore Village, Daman       Daman  396210.0
# 133                      Bhimpore Village, Daman       Daman  396210.0
# 209                Near Calcutta Tramway Company     Kolkata  700001.0
# 210                Near Calcutta Tramway Company     Kolkata  700001.0
# 248           Near Citi Industrial Estate, Udhna       Udhna  394210.0
# 249           Near Citi Industrial Estate, Udhna       Udhna  394210.0
# 273                              Raipur District    Paragaon  493885.0
# 274                              Raipur District    Paragaon  493885.0
# 680                                          NaN    Kashipur  244713.0
# 681                                          NaN    Kashipur  244713.0
# 740                       National Highway No.8,        Vapi  396191.0
# 744                       National Highway No.8,        Vapi  396191.0
# 805  Anandapuram Mandal, Visakhapatnam District,  Peddipalem  531163.0
# 806  Anandapuram Mandal, Visakhapatnam District,  Peddipalem  531163.0
# 823                                     Sivakasi    Sivakasi  626123.0
# 824                                     Sivakasi    Sivakasi  626123.0
#
#             Taluk          District           State  \
# 99            NaN        Aurangabad     Maharashtra
# 100           NaN        Aurangabad     Maharashtra
# 130           NaN               NaN     Daman & Diu
# 133           NaN               NaN     Daman & Diu
# 209           NaN               NaN     West Bengal
# 210           NaN               NaN     West Bengal
# 248           NaN             Surat         Gujarat
# 249           NaN             Surat         Gujarat
# 273  Baloda Bazar            Raipur    Chhattisgarh
# 274  Baloda Bazar            Raipur    Chhattisgarh
# 680           NaN  Udhamsingh Nagar     Uttaranchal
# 681           NaN  Udhamsingh Nagar     Uttaranchal
# 740           NaN            Valsad         Gujarat
# 744           NaN            Valsad         Gujarat
# 805   Anandapuram     Visakhapatnam  Andhra Pradesh
# 806   Anandapuram     Visakhapatnam  Andhra Pradesh
# 823           NaN      Virudhunagar      Tamil Nadu
# 824           NaN      Virudhunagar      Tamil Nadu
#
#                                Tel           Fax  \
# 99          0240 248 2633/248 3131           NaN
# 100         0240 248 2633/248 3131           NaN
# 130                0260 - 661 8700           NaN
# 133                0260 - 661 8700           NaN
# 209                  0-98303 19277           NaN
# 210                  0-98303 19277           NaN
# 248                   0-9687644501           NaN
# 249                   0-9687644501           NaN
# 273      Tel: 07701- 233922/233219   Fax: 233689
# 274      Tel: 07701- 233922/233219   Fax: 233689
# 680        Tel: 0131-2468388 / 89,  Fax: 2468391
# 681        Tel: 0131-2468388 / 89,  Fax: 2468391
# 740              0260 2437159 / 60           NaN
# 744              0260 2437159 / 60           NaN
# 805  Tel: 0-8933222296, 8933222297           NaN
# 806    Tel: 8933222296, 8933222297           NaN
# 823           04562 284022, 284155  04562 284011
# 824           04562 284022, 284155  04562 284011
#
#                                          Email Names Capacity Units  \
# 99                      bedsepaper@yahoo.co.in   NaN      NaN   NaN
# 100                     bedsepaper@yahoo.co.in   NaN      NaN   NaN
# 130                       bppld@borkarpack.com   NaN      NaN   NaN
# 133                       bppld@borkarpack.com   NaN      NaN   NaN
# 209                      eipplhaldia@gmail.com   NaN      NaN   NaN
# 210                      eipplhaldia@gmail.com   NaN      NaN   NaN
# 248                                        NaN   NaN      NaN   NaN
# 249                     girija.craft@yahoo.com   NaN      NaN   NaN
# 273                  Email: hail@sancharnet.in   NaN      NaN   NaN
# 274                  Email: hail@sancharnet.in   NaN      2.5    MW
# 680                Email: bppl_mzn@yahoo.co.in   NaN    13500   tpa
# 681                Email: bppl_mzn@yahoo.co.in   NaN    17800   tpa
# 740          speciality@reliablepaperindia.com   NaN      NaN   NaN
# 744          speciality@reliablepaperindia.com   NaN      NaN   NaN
# 805                                        NaN   NaN      NaN   NaN
# 806                                        NaN   NaN      NaN   NaN
# 823  sales@scbmpl.com, sales@supremegroups.org   NaN      NaN   NaN
# 824  sales@scbmpl.com, sales@supremegroups.org   NaN      NaN   NaN
#
#     Upcoming Capacity Units.1 Captive Power Plant Capacity
# 99                NaN     NaN                          NaN
# 100               NaN     NaN                          NaN
# 130               NaN     NaN                          NaN
# 133               NaN     NaN                          NaN
# 209               NaN     NaN                          NaN
# 210               NaN     NaN                          NaN
# 248               NaN     NaN                          NaN
# 249               NaN     NaN                          NaN
# 273               NaN     NaN                          NaN
# 274               NaN     NaN                          NaN
# 680               NaN     NaN                          NaN
# 681               NaN     NaN                         6 MW
# 740               NaN     NaN                          NaN
# 744               NaN     NaN                          NaN
# 805               NaN     NaN                          NaN
# 806               NaN     NaN                          NaN
# 823               NaN     NaN                          NaN
# 824               NaN     NaN                          NaN

# %% [markdown]
# ### Cleaning Column names and Columns

# %%
cols = df.columns

cols = [x.replace(" ", "_").lower() for x in cols]

cols
# Out:
# ['company_name',
#  'add1',
#  'add2',
#  'city',
#  'pincode',
#  'taluk',
#  'district',
#  'state',
#  'tel',
#  'fax',
#  'email',
#  'names',
#  'capacity',
#  'units',
#  'upcoming_capacity',
#  'units.1',
#  'captive_power_plant_capacity']

# %%
df.columns = cols

df.rename(columns={
    "units.1":"upcoming_capacity_unit"
}, inplace=True)
# Out:
# /tmp/ipykernel_5119/461494988.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={

# %%
df.drop(['tel',
 'fax',
 'email',
 'names',
 'captive_power_plant_capacity'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_5119/3798550352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['tel',

# %%
df.to_csv(export_path, index=False)
