# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
dir_path = Path.cwd().parents[2]

data_folder = dir_path.joinpath("data/ibis/raw_manually_sorted")

df_path = data_folder.joinpath("Fertilizer.xlsx")

export_path = dir_path.joinpath("data/ibis/interim/Fertilizer.csv")

# %%
df = pd.read_excel(df_path)
df
# Out:
#                       Company Name AddCode  \
# 0           A B Composites Pvt Ltd   Plant
# 1    A Choksey Chemical Industries   Plant
# 2        A P India Biotech Pvt Ltd   Plant
# 3        A P India Biotech Pvt Ltd   Plant
# 4           A Saj Agricare Pvt Ltd   Plant
# ..                             ...     ...
# 646    Yawalkar Pesticides Pvt Ltd   Plant
# 647        Yoshi Crop Care Pvt Ltd   Plant
# 648           Zany Biotech Pvt Ltd   Plant
# 649      Zinco Chemical Industries   Plant
# 650       Zuari Agro Chemicals Ltd   Plant
#
#                                             Add1                        Add2  \
# 0    P-24, Phase - III, Kasba Industrial Estate,                         NaN
# 1                        8-A.Udhana, Udyognagar,           P.B.No.19,Udhana,
# 2                                Industrial Area                  Deewanganj
# 3                      Meghnagar Industrial Area                     Jhabhua
# 4                      K-1/16/21-22, GIDC Dabhoi             Industrial Area
# ..                                           ...                         ...
# 646             51-59, Nagpur Industrial Estate,      Uppalwadi Kamthi Road,
# 647         Plot No. H-34, Kosi Kotwan Extension      UPSIDC Industrial Area
# 648                                      Dinhata                 Cooch Behar
# 649                 A/2,22/2 23, G.I.D.C. Estate                       Kalol
# 650                                  Zuarinagar,  Sancoale Village, Mormugao
#
#                         City   Pincode Taluk      District           State  \
# 0                   Kolkatta  700107.0   NaN           NaN     West Bengal
# 1                      Surat  395007.0   NaN         Surat         Gujarat
# 2                 Deewanganj  464651.0   NaN        Raisen  Madhya Pradesh
# 3                  Meghnagar  457779.0   NaN        Jhabua  Madhya Pradesh
# 4                     Dabhoi  391110.0   NaN      Vadodara         Gujarat
# ..                       ...       ...   ...           ...             ...
# 646                  Kamptee  440026.0   NaN        Nagpur     Maharashtra
# 647               Kosi Kalan  281403.0   NaN       Mathura   Uttar Pradesh
# 648                  Dinhata  736135.0   NaN   Cooch Behar     West Bengal
# 649  Kalol Industrial Estate  382725.0   NaN  Gandhi Nagar         Gujarat
# 650                 Mormugoa  403803.0   NaN     South Goa             Goa
#
#                                          Tel                  Fax  \
# 0                                        NaN                  NaN
# 1                        Tel: 0261 - 2278546  Fax: 0261 - 2278345
# 2                                        NaN                  NaN
# 3                                        NaN                  NaN
# 4                          Tel: 02663-254802                  NaN
# ..                                       ...                  ...
# 646                   0712-2996890 / 2640330                  NaN
# 647                                      NaN                  NaN
# 648                                      NaN                  NaN
# 649  Tel: 02764-220135, 228565 /098793 99644    Fax: 02764-228565
# 650                                      NaN                  NaN
#
#                                  Email Names Capacity Unit Upcoming Capacity  \
# 0                                  NaN   NaN      NaN  NaN               NaN
# 1    Email: achoksey_surat@yahoo.co.in   NaN      NaN  NaN               NaN
# 2                                  NaN   NaN      NaN  NaN               NaN
# 3                                  NaN   NaN      NaN  NaN               NaN
# 4                                  NaN   NaN      NaN  NaN               NaN
# ..                                 ...   ...      ...  ...               ...
# 646     yawalkarpesticides@yahoo.co.in   NaN      NaN  NaN               NaN
# 647                                NaN   NaN      NaN  NaN              5100
# 648                                NaN   NaN      100  tpd               NaN
# 649     Email: zincochemical@gmail.com   NaN      NaN  NaN               NaN
# 650                                NaN   NaN      NaN  NaN               NaN
#
#     Units Captive Power Plant Capacity
# 0     NaN                          NaN
# 1     NaN                          NaN
# 2     NaN                          NaN
# 3     NaN                          NaN
# 4     NaN                          NaN
# ..    ...                          ...
# 646   NaN                          NaN
# 647   tpa                          NaN
# 648   NaN                          NaN
# 649   NaN                          NaN
# 650   NaN                          NaN
#
# [651 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Company Name', 'AddCode', 'Add1', 'Add2', 'City', 'Pincode', 'Taluk',
#        'District', 'State', 'Tel', 'Fax', 'Email', 'Names', 'Capacity', 'Unit',
#        'Upcoming Capacity', 'Units', 'Captive Power Plant Capacity'],
#       dtype='object')

# %% [markdown]
# ### Filtering Plants

# %%
df['AddCode'].unique()
# Out:
# array(['Plant', 'Corp Office', 'Branch Office', 'Project Office'],
#       dtype=object)

# %%
df = df[df['AddCode']=='Plant']
df.drop('AddCode',axis=1, inplace=True)
# Out:
# /tmp/ipykernel_205389/1743636810.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('AddCode',axis=1, inplace=True)

# %% [markdown]
# ### Check Duplicates

# %%
df[df.duplicated(keep=False)]
# Out:
#                            Company Name                                Add1  \
# 605  Thakker Chemical & Fertilizers Ltd  Plot No. 165/B-7, 2nd Phase, GIDC,
# 606  Thakker Chemical & Fertilizers Ltd  Plot No. 165/B-7, 2nd Phase, GIDC,
#
#     Add2  City   Pincode Taluk District    State  \
# 605  NaN  Vapi  396195.0   NaN   Valsad  Gujarat
# 606  NaN  Vapi  396195.0   NaN   Valsad  Gujarat
#
#                                Tel  Fax Email Names Capacity Unit  \
# 605  Tel: 0260-2451480 /9377010317  NaN   NaN   NaN      NaN  NaN
# 606  Tel: 0260-2451480 /9377010317  NaN   NaN   NaN      NaN  NaN
#
#     Upcoming Capacity Units Captive Power Plant Capacity
# 605               NaN   NaN                          NaN
# 606               NaN   NaN                          NaN

# %%
isid_cols = ['Company Name', 'Pincode', 'Add1', 'Add2']


df[df.duplicated(isid_cols,keep=False)]
# Out:
#                            Company Name  \
# 312                   Innova Industries
# 313                   Innova Industries
# 338   KGS Sugar & Infra Corporation Ltd
# 339   KGS Sugar & Infra Corporation Ltd
# 550       Singham Bio Crop Care Pvt Ltd
# 551       Singham Bio Crop Care Pvt Ltd
# 605  Thakker Chemical & Fertilizers Ltd
# 606  Thakker Chemical & Fertilizers Ltd
#
#                                                   Add1  \
# 312                      Plot No. 785/1, 40 Shed Area,
# 313                      Plot No. 785/1, 40 Shed Area,
# 338  Gat No. 147/4, 148/1/2A & 148/1/1B Pimpalgaon ...
# 339  Gat No. 147/4, 148/1/2A & 148/1/1B Pimpalgaon ...
# 550                     Plot No. 85/B, Dungri Village,
# 551                     Plot No. 85/B, Dungri Village,
# 605                 Plot No. 165/B-7, 2nd Phase, GIDC,
# 606                 Plot No. 165/B-7, 2nd Phase, GIDC,
#
#                                          Add2              City   Pincode  \
# 312                                     GIDC,              Vapi  396195.0
# 313                                     GIDC,              Vapi  396195.0
# 338  Talwade - Sulewadi Road, Taluka : Niphad  Nashik Road Camp  422102.0
# 339  Talwade - Sulewadi Road, Taluka : Niphad  Nashik Road Camp  422102.0
# 550                                   Valiya,             Valia  393135.0
# 551                                   Valiya,             Valia  393135.0
# 605                                       NaN              Vapi  396195.0
# 606                                       NaN              Vapi  396195.0
#
#     Taluk District        State                            Tel  Fax  \
# 312   NaN   Valsad      Gujarat  Tel: 0260-2427280 /9825116135  NaN
# 313   NaN   Valsad      Gujarat  Tel: 0260-2427280 /9825116135  NaN
# 338   NaN   Nashik  Maharashtra   Tel: 02550- 2338041, 2338741  NaN
# 339   NaN   Nashik  Maharashtra    Tel: 02550-2338041, 2338741  NaN
# 550   NaN  Bharuch      Gujarat                Tel: 7624051111  NaN
# 551   NaN  Bharuch      Gujarat   Tel: 7624051111 / 9898901114  NaN
# 605   NaN   Valsad      Gujarat  Tel: 0260-2451480 /9377010317  NaN
# 606   NaN   Valsad      Gujarat  Tel: 0260-2451480 /9377010317  NaN
#
#                            Email                Names  Capacity  Unit  \
# 312       Email: innova@vsnl.net                  NaN       NaN   NaN
# 313                          NaN                  NaN       NaN   NaN
# 338  Email: admnkgs@kgssugar.com  Plant Make : VIJSUN      4500   tcd
# 339  Email: admnkgs@kgssugar.com                  NaN        12    MW
# 550                          NaN                  NaN  1,20,000  mtpa
# 551                          NaN                  NaN       NaN   NaN
# 605                          NaN                  NaN       NaN   NaN
# 606                          NaN                  NaN       NaN   NaN
#
#     Upcoming Capacity Units Captive Power Plant Capacity
# 312               NaN   NaN                          NaN
# 313               NaN   NaN                          NaN
# 338               NaN   NaN                          NaN
# 339                15    MW                          NaN
# 550               NaN   NaN                          NaN
# 551               NaN   NaN                          NaN
# 605               NaN   NaN                          NaN
# 606               NaN   NaN                          NaN

# %% [markdown]
# ### Cleaning Column names and Columns

# %%
cols = df.columns

cols = [x.replace(" ", "_").lower() for x in cols]

cols
# Out:
# ['company_name',
#  'add1',
#  'add2',
#  'city',
#  'pincode',
#  'taluk',
#  'district',
#  'state',
#  'tel',
#  'fax',
#  'email',
#  'names',
#  'capacity',
#  'unit',
#  'upcoming_capacity',
#  'units',
#  'captive_power_plant_capacity']

# %%
df.columns = cols

df.rename(columns={
   "units":"upcoming_capacity_unit"
}, inplace=True)
# Out:
# /tmp/ipykernel_205389/1570858624.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={

# %%
df.drop(['tel',
 'fax',
 'email',
 'names',
 'captive_power_plant_capacity'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_205389/3798550352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['tel',

# %%
df
# Out:
#                       company_name  \
# 0           A B Composites Pvt Ltd
# 1    A Choksey Chemical Industries
# 2        A P India Biotech Pvt Ltd
# 3        A P India Biotech Pvt Ltd
# 4           A Saj Agricare Pvt Ltd
# ..                             ...
# 646    Yawalkar Pesticides Pvt Ltd
# 647        Yoshi Crop Care Pvt Ltd
# 648           Zany Biotech Pvt Ltd
# 649      Zinco Chemical Industries
# 650       Zuari Agro Chemicals Ltd
#
#                                             add1                        add2  \
# 0    P-24, Phase - III, Kasba Industrial Estate,                         NaN
# 1                        8-A.Udhana, Udyognagar,           P.B.No.19,Udhana,
# 2                                Industrial Area                  Deewanganj
# 3                      Meghnagar Industrial Area                     Jhabhua
# 4                      K-1/16/21-22, GIDC Dabhoi             Industrial Area
# ..                                           ...                         ...
# 646             51-59, Nagpur Industrial Estate,      Uppalwadi Kamthi Road,
# 647         Plot No. H-34, Kosi Kotwan Extension      UPSIDC Industrial Area
# 648                                      Dinhata                 Cooch Behar
# 649                 A/2,22/2 23, G.I.D.C. Estate                       Kalol
# 650                                  Zuarinagar,  Sancoale Village, Mormugao
#
#                         city   pincode taluk      district           state  \
# 0                   Kolkatta  700107.0   NaN           NaN     West Bengal
# 1                      Surat  395007.0   NaN         Surat         Gujarat
# 2                 Deewanganj  464651.0   NaN        Raisen  Madhya Pradesh
# 3                  Meghnagar  457779.0   NaN        Jhabua  Madhya Pradesh
# 4                     Dabhoi  391110.0   NaN      Vadodara         Gujarat
# ..                       ...       ...   ...           ...             ...
# 646                  Kamptee  440026.0   NaN        Nagpur     Maharashtra
# 647               Kosi Kalan  281403.0   NaN       Mathura   Uttar Pradesh
# 648                  Dinhata  736135.0   NaN   Cooch Behar     West Bengal
# 649  Kalol Industrial Estate  382725.0   NaN  Gandhi Nagar         Gujarat
# 650                 Mormugoa  403803.0   NaN     South Goa             Goa
#
#     capacity unit upcoming_capacity upcoming_capacity_unit
# 0        NaN  NaN               NaN                    NaN
# 1        NaN  NaN               NaN                    NaN
# 2        NaN  NaN               NaN                    NaN
# 3        NaN  NaN               NaN                    NaN
# 4        NaN  NaN               NaN                    NaN
# ..       ...  ...               ...                    ...
# 646      NaN  NaN               NaN                    NaN
# 647      NaN  NaN              5100                    tpa
# 648      100  tpd               NaN                    NaN
# 649      NaN  NaN               NaN                    NaN
# 650      NaN  NaN               NaN                    NaN
#
# [641 rows x 12 columns]

# %%
df.to_csv(export_path, index=False)
